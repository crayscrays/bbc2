# %%
from PIL import Image, ImageOps
from IPython.display import display
import random
import json

# %%
### NECESSARY INFO

backgrounds = ["Lilac", "Mint", "Pink", "Grey", "Baby Blue", "Amber", "Purple Haze", "Sherbert", "Northern Lights", "Downtown", "Tag it", "Gold"] #5 types
backgroundweights = [18, 16, 14, 14, 14, 7.5, 6.5, 3, 2.5, 2.25, 1.75, 0.5]

bananas = ["Yellow", "Blue", "Green", "Red", "Pride", "Iridescent", "Gold", "Peeled", "Peeled Pickle", "Diamond", "Psychedelic", "Wonderland", "Candy Camo", "Camo", "Emerald", "Ruby","Stripes"] #7 types
bananaweights = [20.5, 19, 17.5, 16.75, 9.5, 6.5, 0.5, 1.75, 0.75, 0.25, 1.5, 1.65, 0.75, 1, 0.5, 0.35, 1.25]

mouths = ["Smirk", "Toothless", "Grrrr", "Pipe", "Doobie", "Lollipop", "Cigar", "Toothpick", "Beatnik", "Meh", "Handlebar 'stache", "Cherry Lips", "Whoops", "Trashy", "Bubblegum", "Tongue Ring", "Sulking", "The Douche", "Happy", "Outbreak", "Dystopia", "Whistle"] #7 types
mouthweights = [8, 6, 6, 4, 3, 4, 3, 6, 9, 9, 9, 9, 1, 2, 3, 5, 2, 1, 5, 0.5, 0.5, 4]

eyes = ["Bored", "Cyberpunk", "Steampunk", "Pixel", "Michelangelo", "Leonardo", "Donatello", "Raphael", "Cyclops", "Googly", "Hypno", "Stoner", "Trippy", "The Green Gaze", "Hangover", "3D", "Wazowski", "Carnival", "Flirty", "Cross-eyed", "Mysterious", "Bulge", "Yuyu", "Supastar", "Perplexed", "Geeky", "Conductor", "Bana-love", "Eye-patch"] #12 types
eyesweights = [7.5, 5.5, 1.5, 6, 4.5, 4, 4, 3.5, 2, 5.5, 5, 4.25, 3.5, 0.5, 4, 4.5, 2, 1, 5.5, 2.5, 0.5, 3.5, 0.5, 0.25, 6.5, 4.5, 2, 2.5, 3]

headgears = ["Carrot Top", "Vintage", "Tuft", "Wilma", "Spike", "Bowl", "Cotton Candy", "Toupet", "Sidewinder", "Hair Stick", "Fury", "Abu", "Deputy", "Sheriff ", "Goku", "Ryu", "Raiden", "Mullet", "Astronaut", "Goofy", "Donald Duck", "Boogie-Beanie", "Bleach", "Angry Bird", "Sporty", "Quinn", "Rapunzel", "Bonnet", "Crown", "Jester", "Tiara", "Angel", "Demon", "Ahoy", "DJ", "Dood"] # 28 types
headgearweights = [4.2, 3.8, 3, 3.6, 2.5, 3.7, 3.2, 4.2, 4.3, 4.2, 3.8, 3.7, 4.2, 1.9, 3.2, 2.1, 3.1, 3.5, 1.4, 4.2, 3, 2.6, 4, 0.2, 4.2, 1.7, 1, 3.8, 0.6, 0.4, 0.3, 0.75, 0.75, 3.5, 2.5, 2.9]



backgroundfiles = {
    "Lilac": "bg1",
    "Mint": "bg2",
    "Pink": "bg3",
    "Grey": "bg4",
    "Baby Blue": "bg5",
    "Amber": "bg6",
    "Purple Haze": "bg7",
    "Sherbert": "bg8",
    "Northern Lights": "bg9",
    "Downtown": "bg10",
    "Tag it": "bg11",
    "Gold": "bg12"
}

bananafiles = {
    "Yellow" : "bn1",
    "Blue" : "bn2",
    "Green" : "bn3",
    "Red" : "bn4",
    "Pride" : "bn5",
    "Iridescent" : "bn6",
    "Gold" : "bn7",
    "Peeled" : "bn8",
    "Peeled Pickle" : "bn9",
    "Diamond" : "bn10",
    "Psychedelic" : "bn11",
    "Wonderland" : "bn12",
    "Candy Camo" : "bn13",
    "Camo" : "bn14",
    "Rotten " : "bn15",
    "Dirty Naked" : "bn16",
    "Emerald" : "bn17",
    "Ruby" : "bn18",
    "Stripes" : "bn19",
}

mouthfiles = {
    
    "Smirk" : "mo1",
    "Toothless" : "mo2",
    "Grrrr" : "mo3",
    "Pipe" : "mo4",
    "Doobie" : "mo5",
    "Lollipop" : "mo6",
    "Cigar" : "mo7",
    "Toothpick" : "mo8",
    "Beatnik" : "mo9",
    "Meh" : "mo10",
    "Handlebar 'stache" : "mo11",
    "Cherry Lips" : "mo12",
    "Whoops" : "mo13",
    "Trashy" : "mo14",
    "Bubblegum" : "mo15",
    "Tongue Ring" : "mo16",
    "Sulking" : "mo17",
    "The Douche" : "mo18",
    "Happy" : "mo19",
    "Outbreak" : "mo20",
    "Dystopia" : "mo21",
    "Whistle" : "mo22"
     
}

eyefiles = {
    "Bored": "ey1",
    "Cyberpunk": "ey2",
    "Steampunk": "ey3",
    "Pixel": "ey4",
    "Michelangelo": "ey5",
    "Leonardo": "ey6",
    "Donatello": "ey7",
    "Raphael": "ey8",
    "Cyclops": "ey9",
    "Googly": "ey10",
    "Hypno": "ey11",
    "Stoner": "ey12",
    "Trippy": "ey13",
    "The Green Gaze": "ey14",
    "Hangover": "ey15",
    "3D": "ey16",
    "Wazowski": "ey17",
    "Carnival": "ey18",
    "Flirty": "ey19",
    "Cross-eyed": "ey20",
    "Mysterious": "ey21",
    "Bulge": "ey22",
    "Yuyu": "ey23",
    "Supastar": "ey24",
    "Perplexed": "ey25",
    "Geeky": "ey26",
    "Conductor": "ey27",
    "Bana-love": "ey28",
    "Eye-patch": "ey29"
}

headgearfiles = {
    "Carrot Top" : "he1",
    "Vintage" : "he2",
    "Tuft" : "he3",
    "Wilma" : "he4",
    "Spike" : "he5",
    "Bowl" : "he6",
    "Cotton Candy" : "he7",
    "Toupet" : "he8",
    "Sidewinder" : "he9",
    "Hair Stick" : "he10",
    "Fury" : "he11",
    "Abu" : "he12",
    "Deputy" : "he13",
    "Sheriff " : "he14",
    "Goku" : "he15",
    "Ryu" : "he16",
    "Raiden" : "he17",
    "Mullet" : "he18",
    "Astronaut" : "he19",
    "Goofy" : "he20",
    "Donald Duck" : "he21",
    "Boogie-Beanie" : "he22",
    "Bleach" : "he23",
    "Angry Bird" : "he24",
    "Sporty" : "he25",
    "Quinn" : "he26",
    "Rapunzel" : "he27",
    "Bonnet" : "he28",
    "Crown" : "he29",
    "Jester" : "he30",
    "Tiara" : "he31",
    "Angel" : "he32",
    "Demon" : "he33",
    "Ahoy" : "he34",
    "DJ" : "he35",
    "Dood" : "he36",
}

# %%
## TRAIT GENERATION

TOTAL_BANANAS = 8888

traits = []

def createCombo():
    
    trait = {}

    trait["Background"] = random.choices(backgrounds, backgroundweights)[0]
    trait["Banana Base"] = random.choices(bananas, bananaweights)[0]
    trait["Mouth"] = random.choices(mouths, mouthweights)[0]
    trait["Eyes"] = random.choices(eyes, eyesweights)[0]
    trait["Head Gear"] = random.choices(headgears, headgearweights)[0]
    
    if trait in traits:
        return createCombo()
    else:
        return trait
    
for i in range(TOTAL_BANANAS):
    
    newtraitcombo = createCombo()
    
    traits.append(newtraitcombo)

# %%
## ARE ALL BANANAS UNIQUE? I DUNNO HOW THIS WORKS BUT IT WORKS
def allUnique(x):
    seen = list()
    return not any(i in seen or seen.append(i) for i in x)

print(allUnique(traits))
# Out:
# True

# %%
# ADD TOKEN IDS TO JSON

i = 0
for item in traits:
    item["tokenId"] = i
    i = i + 1

# %%
# PRINT THE SHIT

print(traits)
# Out:
# [{'Background': 'Baby Blue', 'Banana Base': 'Camo', 'Mouth': 'Dystopia', 'Eyes': 'Stoner', 'Head Gear': 'Raiden', 'tokenId': 0}, {'Background': 'Amber', 'Banana Base': 'Green', 'Mouth': 'Lollipop', 'Eyes': 'Googly', 'Head Gear': 'Vintage', 'tokenId': 1}, {'Background': 'Grey', 'Banana Base': 'Yellow', 'Mouth': 'Pipe', 'Eyes': 'Michelangelo', 'Head Gear': 'Raiden', 'tokenId': 2}, {'Background': 'Baby Blue', 'Banana Base': 'Diamond', 'Mouth': "Handlebar 'stache", 'Eyes': 'Trippy', 'Head Gear': 'Fury', 'tokenId': 3}, {'Background': 'Lilac', 'Banana Base': 'Green', 'Mouth': 'Smirk', 'Eyes': 'Bulge', 'Head Gear': 'Goku', 'tokenId': 4}, {'Background': 'Grey', 'Banana Base': 'Blue', 'Mouth': "Handlebar 'stache", 'Eyes': 'Bored', 'Head Gear': 'Astronaut', 'tokenId': 5}, {'Background': 'Purple Haze', 'Banana Base': 'Stripes', 'Mouth': 'Beatnik', 'Eyes': 'Flirty', 'Head Gear': 'Rapunzel', 'tokenId': 6}, {'Background': 'Mint', 'Banana Base': 'Candy Camo', 'Mouth': 'Tongue Ring', 'Eyes': 'Flirty', 'Head Gear': 'Toupet', 'tokenId': 7}, {'Background': 'Baby Blue', 'Banana Base': 'Psychedelic', 'Mouth': 'Cherry Lips', 'Eyes': 'Bored', 'Head Gear': 'Sidewinder', 'tokenId': 8}, {'Background': 'Baby Blue', 'Banana Base': 'Yellow', 'Mouth': 'Meh', 'Eyes': 'Bana-love', 'Head Gear': 'Dood', 'tokenId': 9}, {'Background': 'Grey', 'Banana Base': 'Yellow', 'Mouth': 'Lollipop', 'Eyes': 'Cyberpunk', 'Head Gear': 'Wilma', 'tokenId': 10}, {'Background': 'Lilac', 'Banana Base': 'Yellow', 'Mouth': 'Dystopia', 'Eyes': 'Pixel', 'Head Gear': 'Carrot Top', 'tokenId': 11}, {'Background': 'Pink', 'Banana Base': 'Green', 'Mouth': "Handlebar 'stache", 'Eyes': 'Conductor', 'Head Gear': 'DJ', 'tokenId': 12}, {'Background': 'Grey', 'Banana Base': 'Wonderland', 'Mouth': 'Meh', 'Eyes': 'Stoner', 'Head Gear': 'Carrot Top', 'tokenId': 13}, {'Background': 'Sherbert', 'Banana Base': 'Red', 'Mouth': 'Grrrr', 'Eyes': 'Steampunk', 'Head Gear': 'Wilma', 'tokenId': 14}, {'Background': 'Baby Blue', 'Banana Base': 'Green', 'Mouth': 'Cigar', 'Eyes': 'Donatello', 'Head Gear': 'Spike', 'tokenId': 15}, {'Background': 'Downtown', 'Banana Base': 'Blue', 'Mouth': 'Beatnik', 'Eyes': 'Donatello', 'Head Gear': 'Goofy', 'tokenId': 16}, {'Background': 'Lilac', 'Banana Base': 'Psychedelic', 'Mouth': 'The Douche', 'Eyes': 'Cyberpunk', 'Head Gear': 'Bleach', 'tokenId': 17}, {'Background': 'Lilac', 'Banana Base': 'Red', 'Mouth': 'Cherry Lips', 'Eyes': 'Trippy', 'Head Gear': 'Hair Stick', 'tokenId': 18}, {'Background': 'Lilac', 'Banana Base': 'Pride', 'Mouth': 'Grrrr', 'Eyes': 'Googly', 'Head Gear': 'Goofy', 'tokenId': 19}, {'Background': 'Purple Haze', 'Banana Base': 'Blue', 'Mouth': "Handlebar 'stache", 'Eyes': 'Bored', 'Head Gear': 'Sporty', 'tokenId': 20}, {'Background': 'Mint', 'Banana Base': 'Green', 'Mouth': "Handlebar 'stache", 'Eyes': '3D', 'Head Gear': 'Goku', 'tokenId': 21}, {'Background': 'Grey', 'Banana Base': 'Blue', 'Mouth': 'Beatnik', 'Eyes': 'Perplexed', 'Head Gear': 'Sidewinder', 'tokenId': 22}, {'Background': 'Amber', 'Banana Base': 'Pride', 'Mouth': 'Beatnik', 'Eyes': 'Perplexed', 'Head Gear': 'Sidewinder', 'tokenId': 23}, {'Background': 'Sherbert', 'Banana Base': 'Green', 'Mouth': 'Bubblegum', 'Eyes': 'Cyberpunk', 'Head Gear': 'Ahoy', 'tokenId': 24}, {'Background': 'Grey', 'Banana Base': 'Blue', 'Mouth': 'Toothpick', 'Eyes': 'Perplexed', 'Head Gear': 'Sidewinder', 'tokenId': 25}, {'Background': 'Grey', 'Banana Base': 'Blue', 'Mouth': 'Pipe', 'Eyes': 'Trippy', 'Head Gear': 'Raiden', 'tokenId': 26}, {'Background': 'Lilac', 'Banana Base': 'Yellow', 'Mouth': 'Beatnik', 'Eyes': 'Raphael', 'Head Gear': 'Ryu', 'tokenId': 27}, {'Background': 'Lilac', 'Banana Base': 'Yellow', 'Mouth': 'Happy', 'Eyes': 'Trippy', 'Head Gear': 'Wilma', 'tokenId': 28}, {'Background': 'Amber', 'Banana Base': 'Green', 'Mouth': 'Sulking', 'Eyes': 'Bored', 'Head Gear': 'Vintage', 'tokenId': 29}, {'Background': 'Purple Haze', 'Banana Base': 'Pride', 'Mouth': 'Beatnik', 'Eyes': 'Michelangelo', 'Head Gear': 'Raid ...

# %%
# GET TRAIT COUNTS

backgroundcounts = {}
for item in backgrounds:
    backgroundcounts[item] = 0
    
bananacounts = {}
for item in bananas:
    bananacounts[item] = 0
    
mouthcounts = {}
for item in mouths:
    mouthcounts[item] = 0
    
eyescounts = {}
for item in eyes:
    eyescounts[item] = 0
    
headgearcounts = {}
for item in headgears:
    headgearcounts[item] = 0
    
oneofonecounts = 0

signatures = [137,883,1327,1781,2528,2763,3833,5568,5858,6585,6812,7154,8412]

for banana in traits:
    if banana["tokenId"] in signatures:
        oneofonecounts += 1
    else:    
#     print(banana)
        backgroundcounts[banana["Background"]] += 1
        bananacounts[banana["Banana Base"]] += 1
        mouthcounts[banana["Mouth"]] += 1
        eyescounts[banana["Eyes"]] += 1
        headgearcounts[banana["Head Gear"]] += 1
    
print("background:", backgroundcounts)
print("banana base:", bananacounts)
print("mouth:", mouthcounts)
print("eyes:", eyescounts)
print("headgear:", headgearcounts)
print("1/1:",oneofonecounts)
# Out:
# background: {'Lilac': 1615, 'Mint': 1345, 'Pink': 1253, 'Grey': 1204, 'Baby Blue': 1268, 'Amber': 676, 'Purple Haze': 589, 'Sherbert': 280, 'Northern Lights': 216, 'Downtown': 213, 'Tag it': 166, 'Gold': 50}
# banana base: {'Yellow': 1873, 'Blue': 1694, 'Green': 1547, 'Red': 1450, 'Pride': 858, 'Iridescent': 520, 'Gold': 38, 'Peeled': 161, 'Peeled Pickle': 66, 'Diamond': 24, 'Psychedelic': 125, 'Wonderland': 151, 'Candy Camo': 69, 'Camo': 104, 'Emerald': 50, 'Ruby': 27, 'Stripes': 118}
# mouth: {'Smirk': 750, 'Toothless': 568, 'Grrrr': 526, 'Pipe': 351, 'Doobie': 242, 'Lollipop': 344, 'Cigar': 259, 'Toothpick': 542, 'Beatnik': 806, 'Meh': 790, "Handlebar 'stache": 778, 'Cherry Lips': 818, 'Whoops': 74, 'Trashy': 165, 'Bubblegum': 261, 'Tongue Ring': 442, 'Sulking': 173, 'The Douche': 97, 'Happy': 441, 'Outbreak': 56, 'Dystopia': 43, 'Whistle': 349}
# eyes: {'Bored': 689, 'Cyberpunk': 485, 'Steampunk': 156, 'Pixel': 508, 'Michelangelo': 389, 'Leonardo': 339, 'Donatello': 372, 'Raphael': 322, 'Cyclops': 186, 'Googly': 465, 'Hypno': 442, 'Stoner': 375, 'Trippy': 309, 'The Green Gaze': 33, 'Hangover': 361, '3D': 427, 'Wazowski': 157, 'Carnival': 89, 'Flirty': 489, 'Cross-eyed': 205, 'Mysterious': 33, 'Bulge': 299, 'Yuyu': 39, 'Supastar': 30, 'Perplexed': 557, 'Geeky': 418, 'Conductor': 178, 'Bana-love': 241, 'Eye-patch': 282}
# headgear: {'Carrot Top': 363, 'Vintage': 345, 'Tuft': 243, 'Wilma': 321, 'Spike': 217, 'Bowl': 325, 'Cotton Candy': 285, 'Toupet': 370, 'Sidewinder': 386, 'Hair Stick': 390, 'Fury': 313, 'Abu': 331, 'Deputy': 388, 'Sheriff ': 150, 'Goku': 309, 'Ryu': 170, 'Raiden': 277, 'Mullet': 312, 'Astronaut': 129, 'Goofy': 324, 'Donald Duck': 277, 'Boogie-Beanie': 219, 'Bleach': 343, 'Angry Bird': 17, 'Sporty': 390, 'Quinn': 174, 'Rapunzel': 99, 'Bonnet': 347, 'Crown': 60, 'Jester': 39, 'Tiara': 26, 'Angel': 72, 'Demon': 59, 'Ahoy': 326, 'DJ': 207, 'Dood': 272}
# 1/1: 13

# %%
# WRITE METADATA TO JSON FILE

with open('traits2.json', 'w') as outfile:
    json.dump(traits, outfile, indent=4)

# %%
backgroundfiles
# Out:
# {'Lilac': 'bg1',
#  'Mint': 'bg2',
#  'Pink': 'bg3',
#  'Grey': 'bg4',
#  'Baby Blue': 'bg5',
#  'Amber': 'bg6',
#  'Purple Haze': 'bg7',
#  'Sherbert': 'bg8',
#  'Northern Lights': 'bg9',
#  'Downtown': 'bg10',
#  'Tag it': 'bg11',
#  'Gold': 'bg12'}

# %%
#### IMAGE GENERATION
    
for item in traits:

    im1 = Image.open(f'./Backgrounds/{backgroundfiles[item["Background"]]}.jpg').convert('RGBA')
    im2 = Image.open(f'./Bananas/{bananafiles[item["Banana Base"]]}.png').convert('RGBA')
    im3 = Image.open(f'./Mouths/{mouthfiles[item["Mouth"]]}.png').convert('RGBA')
    im4 = Image.open(f'./Eyes/{eyefiles[item["Eyes"]]}.png').convert('RGBA')
    im5 = Image.open(f'./Headgear/{headgearfiles[item["Head Gear"]]}.png').convert('RGBA')
    
    im1 = (im1.resize((400,400), Image.NEAREST))
    im2 = (im2.resize((400,400), Image.NEAREST))
    im3 = (im3.resize((400,400), Image.NEAREST))
    im4 = (im4.resize((400,400), Image.NEAREST))
    im5 = (im5.resize((400,400), Image.NEAREST))
    

    #Create each composite
    com1 = Image.alpha_composite(im1, im2)
    com2 = Image.alpha_composite(com1, im3)
    com3 = Image.alpha_composite(com2, im4)
    com4 = Image.alpha_composite(com3, im5)

    #Convert to RGB
    rgb_im = com4.convert('RGB')
#    display(rgb_im.resize((400,400), Image.NEAREST))

    file_name = str(item["tokenId"]) + ".jpg"
    rgb_im.save("./output/" + file_name)
    print(f'{str(item["tokenId"])} done')
# Out:
# 0 done
# 1 done
# 2 done
# 3 done
# 4 done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27856/3768604053.py in <module>
#       6     im2 = Image.open(f'./Bananas/{bananafiles[item["Banana Base"]]}.png').convert('RGBA')
#       7     im3 = Image.open(f'./Mouths/{mouthfiles[item["Mouth"]]}.png').convert('RGBA')
# ----> 8     im4 = Image.open(f'./Eyes/{eyefiles[item["Eyes"]]}.png').convert('RGBA')
#       9     im5 = Image.open(f'./Headgear/{headgearfiles[item["Head Gear"]]}.png').convert('RGBA')
#      10
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\PIL\Image.py in convert(self, mode, matrix, dither, palette, colors)
#     922                 mode = "RGB"
#     923         if not mode or (mode == self.mode and not matrix):
# --> 924             return self.copy()
#     925
#     926         has_transparency = self.info.get("transparency") is not None
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\PIL\Image.py in copy(self)
#    1149         """
#    1150         self.load()
# -> 1151         return self._new(self.im.copy())
#    1152
#    1153     __copy__ = copy
#
# KeyboardInterrupt:

# %%
# READ METADATA IF YOU ALREADY HAVE A JSON FILE

with open("traitsfinal.json", 'r') as f:
        traits = json.load(f)

# %%
traits[2050]

# %%
flip_ids = [8057, 8835, 8880, 6612, 5788, 8333, 2173, 8704, 7351, 6671, 4847, 5575, 4864, 2418, 2944, 5845, 552, 1161, 2390, 4383, 8126, 439, 1055, 3435, 7957, 1209, 6438, 6578, 6244, 3490, 4149, 8510, 113, 7193, 5728, 4731, 810, 2949, 3158, 1475, 1242, 4137, 7112, 5852, 7845, 3493, 377, 4272, 5494, 2919, 6818, 2828, 1089, 4914, 5054, 160, 3991, 7625, 6265, 8160, 7331, 4802, 1442, 3850, 171, 3469, 193, 7171, 6328, 5852, 6504, 6639, 2637, 1918, 8607, 4460, 5257, 926, 6114, 8428, 8173, 4565, 5857, 2021, 430, 7708, 4799, 8065, 1609, 4807, 5802, 3371, 8722, 5594, 3034, 2087, 3684, 7878, 7908]

# %%
for m in flip_ids:
    img = Image.open(f'./output/{str(m)}.jpg')
    im_mirror = ImageOps.mirror(img)
    im_mirror.save(f'./flipped/{str(m)}.jpg')

# %%
balds = [4378, 7459, 6945, 4644, 5999, 6337, 6675, 4179, 8467, 5482, 4531, 2016, 3790, 1305, 355]

for bald in balds:
    traits[bald]["Head Gear"] = "None"
    
#### BALDS
    
for bald in balds:
    
    item = traits[bald]
    
    im1 = Image.open(f'./Backgrounds/{backgroundfiles[item["Background"]]}.jpg').convert('RGBA')
    im2 = Image.open(f'./Bananas/{bananafiles[item["Banana Base"]]}.png').convert('RGBA')
    im3 = Image.open(f'./Mouths/{mouthfiles[item["Mouth"]]}.png').convert('RGBA')
    im4 = Image.open(f'./Eyes/{eyefiles[item["Eyes"]]}.png').convert('RGBA')
#     im5 = Image.open(f'./Headgear/{headgearfiles[item["Head Gear"]]}.png').convert('RGBA')


    #Create each composite
    com1 = Image.alpha_composite(im1, im2)
    com2 = Image.alpha_composite(com1, im3)
    com3 = Image.alpha_composite(com2, im4)
#     com4 = Image.alpha_composite(com3, im5)

    #Convert to RGB
    rgb_im = com3.convert('RGB')
#     display(rgb_im.resize((400,400), Image.NEAREST))

    file_name = str(item["tokenId"]) + ".jpg"
    rgb_im.save("./balds/" + file_name)
    print(f'{str(item["tokenId"])} done')

# %%
madboogielogos = [ 1334, 8120, 3430, 3439, 4175, 7710, 1842, 2428, 3553, 4764, 3439 ]

# %%
for logo in madboogielogos:

    im1 = Image.open(f'./output2/{logo}.jpg').convert('RGBA')
    im2 = Image.open(f'./Logo_static.png').convert('RGBA')
    com1 = Image.alpha_composite(im1, im2).convert('RGB')
    com1.save(f'./boogielogo/{logo}.jpg')

# %%
traits

# %%
with open('traitsfinal.json', 'w') as outfile:
    json.dump(traits, outfile, indent=4)
