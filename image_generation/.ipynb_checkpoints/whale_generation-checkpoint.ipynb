# %%
from PIL import Image, ImageOps
from IPython.display import display
import random
import json

# %%
### NECESSARY INFO

background = ["Mint", "Baby Cyan", "Baby Yellow", "Baby Pink", "Grey", "Baby Blue"] #6 types
backgroundweights = [20, 20, 20, 12.5, 5, 12.5]

body = ["Blue", "Pink", "Cyan", "Orange", "Pink Purple", "White", "Cyan Blue", "Koi", "Calico", "Dalmation", "Black"] #11 types
bodyweights = [15, 12.5, 15, 12.5, 5, 10, 5, 5, 5, 5, 10]

fipper = ["Blue", "Pink", "Cyan", "Pink Purple", "Orange", "White", "Cyan Blue", "Black"] #8 types
fipperweights = [30, 10, 10, 10, 10, 10, 10, 10]

#eyes = ["Bored", "Cyberpunk", "Steampunk", "Pixel", "Michelangelo", "Leonardo", "Donatello", "Raphael", "Cyclops", "Googly", "Hypno", "Stoner", "Trippy", "The Green Gaze", "Hangover", "3D", "Wazowski", "Carnival", "Flirty", "Cross-eyed", "Mysterious", "Bulge", "Yuyu", "Supastar", "Perplexed", "Geeky", "Conductor", "Bana-love", "Eye-patch"] #12 types
#eyesweights = [7.5, 5.5, 1.5, 6, 4.5, 4, 4, 3.5, 2, 5.5, 5, 4.25, 3.5, 0.5, 4, 4.5, 2, 1, 5.5, 2.5, 0.5, 3.5, 0.5, 0.25, 6.5, 4.5, 2, 2.5, 3]

head = ["Holy Water", "Smoke", "Smoke Ring", "Fountain", "None"] # 5 types
headweights = [5, 10, 15, 20, 50]


backgroundfiles = {
    "Mint": "bg1",
    "Baby Cyan": "bg2",
    "Baby Yellow": "bg3",
    "Baby Pink": "bg4",
    "Grey": "bg5",
    "Baby Blue": "bg6"
}

bodyfiles = {
    "Blue" : "body1",
    "Pink" : "body2",
    "Cyan" : "body3",
    "Orange" : "body4",
    "Pink Purple" : "body5",
    "White" : "body6",
    "Cyan Blue" : "body7",
    "Koi" : "body8",
    "Calico" : "body9",
    "Dalmation" : "body10",
    "Black" : "body11"
}

fipperfiles = {
    
    "Blue" : "fipper1",
    "Pink" : "fipper2",
    "Cyan" : "fipper3",
    "Pink Purple" : "fipper4",
    "Orange" : "fipper5",
    "White" : "fipper6",
    "Cyan Blue" : "fipper7",
    "Black" : "fipper8"
     
}

headfiles = {
    "Holy Water" : "head1",
    "Smoke" : "head2",
    "Smoke Ring" : "head3",
    "Fountain" : "head4",
    "None" : "head5"
}

# %%
## TRAIT GENERATION

TOTAL_WHALES = 2640

traits = []

def createCombo():
    
    trait = {}

    trait["Background"] = random.choices(background, backgroundweights)[0]
    trait["Body"] = random.choices(body, bodyweights)[0]
    trait["Fipper"] = random.choices(fipper, fipperweights)[0]
    trait["Head"] = random.choices(head, headweights)[0]
    
    if trait in traits:
        return createCombo()
    else:
        return trait
    
for i in range(TOTAL_WHALES):
    
    newtraitcombo = createCombo()
    
    traits.append(newtraitcombo)

# %%
## ARE ALL BANANAS UNIQUE? I DUNNO HOW THIS WORKS BUT IT WORKS
def allUnique(x):
    seen = list()
    return not any(i in seen or seen.append(i) for i in x)

print(allUnique(traits))
# Out:
# True

# %%
# ADD TOKEN IDS TO JSON

i = 0
for item in traits:
    item["tokenId"] = i
    i = i + 1

# %%
# PRINT THE SHIT

print(traits)
# Out:
# [{'Background': 'Pink', 'Banana Base': 'Iridescent', 'Mouth': "Handlebar 'stache", 'Eyes': 'Hangover', 'Head Gear': 'Spike', 'tokenId': 0}, {'Background': 'Grey', 'Banana Base': 'Iridescent', 'Mouth': 'Smirk', 'Eyes': 'Googly', 'Head Gear': 'Mullet', 'tokenId': 1}, {'Background': 'Lilac', 'Banana Base': 'Green', 'Mouth': 'Toothless', 'Eyes': 'Hypno', 'Head Gear': 'Sidewinder', 'tokenId': 2}, {'Background': 'Purple Haze', 'Banana Base': 'Blue', 'Mouth': 'Bubblegum', 'Eyes': 'Hangover', 'Head Gear': 'Wilma', 'tokenId': 3}, {'Background': 'Baby Blue', 'Banana Base': 'Red', 'Mouth': 'Toothpick', 'Eyes': 'Perplexed', 'Head Gear': 'Astronaut', 'tokenId': 4}, {'Background': 'Grey', 'Banana Base': 'Peeled', 'Mouth': 'Smirk', 'Eyes': 'Cyberpunk', 'Head Gear': 'Hair Stick', 'tokenId': 5}, {'Background': 'Amber', 'Banana Base': 'Gold', 'Mouth': 'Toothpick', 'Eyes': 'Geeky', 'Head Gear': 'Carrot Top', 'tokenId': 6}, {'Background': 'Lilac', 'Banana Base': 'Blue', 'Mouth': 'Smirk', 'Eyes': '3D', 'Head Gear': 'Ryu', 'tokenId': 7}, {'Background': 'Mint', 'Banana Base': 'Red', 'Mouth': 'Toothpick', 'Eyes': 'Bulge', 'Head Gear': 'Dood', 'tokenId': 8}, {'Background': 'Mint', 'Banana Base': 'Green', 'Mouth': 'Toothless', 'Eyes': 'Googly', 'Head Gear': 'Deputy', 'tokenId': 9}, {'Background': 'Lilac', 'Banana Base': 'Blue', 'Mouth': 'Outbreak', 'Eyes': 'Trippy', 'Head Gear': 'Wilma', 'tokenId': 10}, {'Background': 'Grey', 'Banana Base': 'Yellow', 'Mouth': 'Sulking', 'Eyes': '3D', 'Head Gear': 'Sporty', 'tokenId': 11}, {'Background': 'Lilac', 'Banana Base': 'Red', 'Mouth': 'Whistle', 'Eyes': 'Donatello', 'Head Gear': 'Fury', 'tokenId': 12}, {'Background': 'Baby Blue', 'Banana Base': 'Blue', 'Mouth': 'Beatnik', 'Eyes': 'Cyberpunk', 'Head Gear': 'Sporty', 'tokenId': 13}, {'Background': 'Purple Haze', 'Banana Base': 'Green', 'Mouth': 'Meh', 'Eyes': 'Bana-love', 'Head Gear': 'Mullet', 'tokenId': 14}, {'Background': 'Gold', 'Banana Base': 'Peeled', 'Mouth': 'Whistle', 'Eyes': 'Bored', 'Head Gear': 'Sporty', 'tokenId': 15}, {'Background': 'Purple Haze', 'Banana Base': 'Blue', 'Mouth': 'Tongue Ring', 'Eyes': 'Wazowski', 'Head Gear': 'Sporty', 'tokenId': 16}, {'Background': 'Grey', 'Banana Base': 'Yellow', 'Mouth': 'Toothpick', 'Eyes': 'Pixel', 'Head Gear': 'Sporty', 'tokenId': 17}, {'Background': 'Baby Blue', 'Banana Base': 'Blue', 'Mouth': 'Happy', 'Eyes': 'Bored', 'Head Gear': 'Carrot Top', 'tokenId': 18}, {'Background': 'Amber', 'Banana Base': 'Blue', 'Mouth': 'Beatnik', 'Eyes': 'Raphael', 'Head Gear': 'Deputy', 'tokenId': 19}, {'Background': 'Pink', 'Banana Base': 'Emerald', 'Mouth': 'Lollipop', 'Eyes': 'Wazowski', 'Head Gear': 'Mullet', 'tokenId': 20}, {'Background': 'Mint', 'Banana Base': 'Blue', 'Mouth': 'Tongue Ring', 'Eyes': 'Pixel', 'Head Gear': 'Goofy', 'tokenId': 21}, {'Background': 'Mint', 'Banana Base': 'Yellow', 'Mouth': 'Smirk', 'Eyes': '3D', 'Head Gear': 'Wilma', 'tokenId': 22}, {'Background': 'Northern Lights', 'Banana Base': 'Red', 'Mouth': "Handlebar 'stache", 'Eyes': 'Stoner', 'Head Gear': 'DJ', 'tokenId': 23}, {'Background': 'Mint', 'Banana Base': 'Red', 'Mouth': 'Smirk', 'Eyes': 'Stoner', 'Head Gear': 'Sporty', 'tokenId': 24}, {'Background': 'Mint', 'Banana Base': 'Wonderland', 'Mouth': "Handlebar 'stache", 'Eyes': 'Donatello', 'Head Gear': 'Dood', 'tokenId': 25}, {'Background': 'Lilac', 'Banana Base': 'Blue', 'Mouth': 'The Douche', 'Eyes': 'Perplexed', 'Head Gear': 'Cotton Candy', 'tokenId': 26}, {'Background': 'Baby Blue', 'Banana Base': 'Pride', 'Mouth': 'Beatnik', 'Eyes': 'Mysterious', 'Head Gear': 'DJ', 'tokenId': 27}, {'Background': 'Grey', 'Banana Base': 'Green', 'Mouth': 'Trashy', 'Eyes': 'Cyberpunk', 'Head Gear': 'Boogie-Beanie', 'tokenId': 28}, {'Background': 'Grey', 'Banana Base': 'Green', 'Mouth': 'Toothpick', 'Eyes': 'Hangover', 'Head Gear': 'DJ', 'tokenId': 29}, {'Background': 'Northern Lights', 'Banana Base': 'Blue', 'Mouth': 'Meh', 'Eyes': 'Perplexed', 'Head Gear': 'Deputy', 'tokenId': 30}, {'Background': 'Sherbert',  ...

# %%
# GET TRAIT COUNTS

backgroundcounts = {}
for item in backgrounds:
    backgroundcounts[item] = 0
    
bananacounts = {}
for item in bananas:
    bananacounts[item] = 0
    
mouthcounts = {}
for item in mouths:
    mouthcounts[item] = 0
    
eyescounts = {}
for item in eyes:
    eyescounts[item] = 0
    
headgearcounts = {}
for item in headgears:
    headgearcounts[item] = 0
    
oneofonecounts = 0

signatures = [137,883,1327,1781,2528,2763,3833,5568,5858,6585,6812,7154,8412]

for banana in traits:
    if banana["tokenId"] in signatures:
        oneofonecounts += 1
    else:    
#     print(banana)
        backgroundcounts[banana["Background"]] += 1
        bananacounts[banana["Banana Base"]] += 1
        mouthcounts[banana["Mouth"]] += 1
        eyescounts[banana["Eyes"]] += 1
        headgearcounts[banana["Head Gear"]] += 1
    
print("background:", backgroundcounts)
print("banana base:", bananacounts)
print("mouth:", mouthcounts)
print("eyes:", eyescounts)
print("headgear:", headgearcounts)
print("1/1:",oneofonecounts)
# Out:
# background: {'Lilac': 1610, 'Mint': 1406, 'Pink': 1258, 'Grey': 1265, 'Baby Blue': 1214, 'Amber': 671, 'Purple Haze': 594, 'Sherbert': 259, 'Northern Lights': 211, 'Downtown': 184, 'Tag it': 153, 'Gold': 50}
# banana base: {'Yellow': 1839, 'Blue': 1688, 'Green': 1578, 'Red': 1479, 'Pride': 799, 'Iridescent': 545, 'Gold': 57, 'Peeled': 159, 'Peeled Pickle': 67, 'Diamond': 26, 'Psychedelic': 135, 'Wonderland': 156, 'Candy Camo': 75, 'Camo': 78, 'Emerald': 50, 'Ruby': 28, 'Stripes': 116}
# mouth: {'Smirk': 717, 'Toothless': 544, 'Grrrr': 531, 'Pipe': 354, 'Doobie': 243, 'Lollipop': 325, 'Cigar': 273, 'Toothpick': 528, 'Beatnik': 807, 'Meh': 821, "Handlebar 'stache": 789, 'Cherry Lips': 747, 'Whoops': 98, 'Trashy': 180, 'Bubblegum': 270, 'Tongue Ring': 482, 'Sulking': 201, 'The Douche': 82, 'Happy': 463, 'Outbreak': 43, 'Dystopia': 40, 'Whistle': 337}
# eyes: {'Bored': 710, 'Cyberpunk': 506, 'Steampunk': 129, 'Pixel': 517, 'Michelangelo': 388, 'Leonardo': 375, 'Donatello': 333, 'Raphael': 280, 'Cyclops': 185, 'Googly': 501, 'Hypno': 429, 'Stoner': 373, 'Trippy': 334, 'The Green Gaze': 37, 'Hangover': 337, '3D': 373, 'Wazowski': 177, 'Carnival': 86, 'Flirty': 505, 'Cross-eyed': 238, 'Mysterious': 51, 'Bulge': 313, 'Yuyu': 37, 'Supastar': 18, 'Perplexed': 593, 'Geeky': 396, 'Conductor': 178, 'Bana-love': 241, 'Eye-patch': 235}
# headgear: {'Carrot Top': 404, 'Vintage': 320, 'Tuft': 289, 'Wilma': 296, 'Spike': 219, 'Bowl': 350, 'Cotton Candy': 299, 'Toupet': 383, 'Sidewinder': 385, 'Hair Stick': 401, 'Fury': 349, 'Abu': 331, 'Deputy': 390, 'Sheriff ': 156, 'Goku': 271, 'Ryu': 177, 'Raiden': 269, 'Mullet': 320, 'Astronaut': 124, 'Goofy': 399, 'Donald Duck': 257, 'Boogie-Beanie': 240, 'Bleach': 312, 'Angry Bird': 14, 'Sporty': 352, 'Quinn': 148, 'Rapunzel': 71, 'Bonnet': 339, 'Crown': 57, 'Jester': 23, 'Tiara': 32, 'Angel': 70, 'Demon': 69, 'Ahoy': 306, 'DJ': 207, 'Dood': 246}
# 1/1: 13

# %%
# WRITE METADATA TO JSON FILE

with open('traits2.json', 'w') as outfile:
    json.dump(traits, outfile, indent=4)

# %%
backgroundfiles
# Out:
# [{'Background': 'Amber',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Whistle',
#   'Eyes': 'Googly',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 0},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Green',
#   'Mouth': 'Doobie',
#   'Eyes': 'Donatello',
#   'Head Gear': 'Ryu',
#   'tokenId': 1},
#  {'Background': 'Grey',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Hypno',
#   'Head Gear': 'DJ',
#   'tokenId': 2},
#  {'Background': 'Pink',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Goofy',
#   'tokenId': 3},
#  {'Background': 'Gold',
#   'Banana Base': 'Pride',
#   'Mouth': 'Trashy',
#   'Eyes': 'Googly',
#   'Head Gear': 'Dood',
#   'tokenId': 4},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Cyclops',
#   'Head Gear': 'Goofy',
#   'tokenId': 5},
#  {'Background': 'Grey',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Meh',
#   'Eyes': 'Bored',
#   'Head Gear': 'Ryu',
#   'tokenId': 6},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Trashy',
#   'Eyes': 'Bulge',
#   'Head Gear': 'Abu',
#   'tokenId': 7},
#  {'Background': 'Amber',
#   'Banana Base': 'Red',
#   'Mouth': 'Beatnik',
#   'Eyes': '3D',
#   'Head Gear': 'Deputy',
#   'tokenId': 8},
#  {'Background': 'Sherbert',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Smirk',
#   'Eyes': 'Bulge',
#   'Head Gear': 'Bonnet',
#   'tokenId': 9},
#  {'Background': 'Pink',
#   'Banana Base': 'Red',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Trippy',
#   'Head Gear': 'Bonnet',
#   'tokenId': 10},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Green',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Steampunk',
#   'Head Gear': 'Deputy',
#   'tokenId': 11},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Bubblegum',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Sheriff ',
#   'tokenId': 12},
#  {'Background': 'Lilac',
#   'Banana Base': 'Green',
#   'Mouth': 'Tongue Ring',
#   'Eyes': '3D',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 13},
#  {'Background': 'Grey',
#   'Banana Base': 'Pride',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Mullet',
#   'tokenId': 14},
#  {'Background': 'Lilac',
#   'Banana Base': 'Green',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Raphael',
#   'Head Gear': 'Goku',
#   'tokenId': 15},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Green',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'DJ',
#   'tokenId': 16},
#  {'Background': 'Lilac',
#   'Banana Base': 'Peeled',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Bulge',
#   'Head Gear': 'Vintage',
#   'tokenId': 17},
#  {'Background': 'Amber',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Bored',
#   'Head Gear': 'Cotton Candy',
#   'tokenId': 18},
#  {'Background': 'Pink',
#   'Banana Base': 'Green',
#   'Mouth': 'Bubblegum',
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'Bonnet',
#   'tokenId': 19},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Conductor',
#   'Head Gear': 'Mullet',
#   'tokenId': 20},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Red',
#   'Mouth': 'Meh',
#   'Eyes': 'Googly',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 21},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Blue',
#   'Mouth': 'Cigar',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Sheriff ',
#   'tokenId': 22},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Pride',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Raphael',
#   'Head Gear': 'Sheriff ',
#   'tokenId': 23},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': 'Happy',
#   'Eyes': 'Wazowski',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 24},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Blue',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Cross-eyed',
#   'Head Gear': 'Fury',
#   'tokenId': 25},
#  {'Background': 'Mint',
#   'Banana Base': 'Emerald',
#   'Mouth': 'Trashy',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Spike',
#   'tokenId': 26},
#  {'Background': 'Northern Lights',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Meh',
#   'Eyes': 'Cross-eyed',
#   'Head Gear': 'Donald Duck',
#   'tokenId': 27},
#  {'Background': 'Lilac',
#   'Banana Base': 'Blue',
#   'Mouth': 'Pipe',
#   'Eyes': 'Googly',
#   'Head Gear': 'Deputy',
#   'tokenId': 28},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Bonnet',
#   'tokenId': 29},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Geeky',
#   'Head Gear': 'Ahoy',
#   'tokenId': 30},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Pipe',
#   'Eyes': 'Cyclops',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 31},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Green',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Cross-eyed',
#   'Head Gear': 'Demon',
#   'tokenId': 32},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Red',
#   'Mouth': 'Meh',
#   'Eyes': 'Bored',
#   'Head Gear': 'Sporty',
#   'tokenId': 33},
#  {'Background': 'Grey',
#   'Banana Base': 'Pride',
#   'Mouth': 'Meh',
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Goofy',
#   'tokenId': 34},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Green',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Hangover',
#   'Head Gear': 'Quinn',
#   'tokenId': 35},
#  {'Background': 'Sherbert',
#   'Banana Base': 'Red',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': '3D',
#   'Head Gear': 'Vintage',
#   'tokenId': 36},
#  {'Background': 'Amber',
#   'Banana Base': 'Green',
#   'Mouth': 'Smirk',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Vintage',
#   'tokenId': 37},
#  {'Background': 'Pink',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Vintage',
#   'tokenId': 38},
#  {'Background': 'Lilac',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Meh',
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Goku',
#   'tokenId': 39},
#  {'Background': 'Amber',
#   'Banana Base': 'Pride',
#   'Mouth': 'Whistle',
#   'Eyes': 'Geeky',
#   'Head Gear': 'Wilma',
#   'tokenId': 40},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Blue',
#   'Mouth': 'Toothless',
#   'Eyes': 'Bored',
#   'Head Gear': 'Toupet',
#   'tokenId': 41},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Red',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Googly',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 42},
#  {'Background': 'Lilac',
#   'Banana Base': 'Blue',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Hypno',
#   'Head Gear': 'Fury',
#   'tokenId': 43},
#  {'Background': 'Sherbert',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Happy',
#   'Eyes': 'Raphael',
#   'Head Gear': 'Angel',
#   'tokenId': 44},
#  {'Background': 'Northern Lights',
#   'Banana Base': 'Green',
#   'Mouth': 'Cigar',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Crown',
#   'tokenId': 45},
#  {'Background': 'Grey',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Whistle',
#   'Eyes': 'Bored',
#   'Head Gear': 'Bowl',
#   'tokenId': 46},
#  {'Background': 'Pink',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Sulking',
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Dood',
#   'tokenId': 47},
#  {'Background': 'Lilac',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Bubblegum',
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 48},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Red',
#   'Mouth': 'Toothless',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Wilma',
#   'tokenId': 49},
#  {'Background': 'Sherbert',
#   'Banana Base': 'Red',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Goofy',
#   'tokenId': 50},
#  {'Background': 'Pink',
#   'Banana Base': 'Blue',
#   'Mouth': 'Meh',
#   'Eyes': 'Googly',
#   'Head Gear': 'Donald Duck',
#   'tokenId': 51},
#  {'Background': 'Pink',
#   'Banana Base': 'Blue',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Bored',
#   'Head Gear': 'Donald Duck',
#   'tokenId': 52},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Ahoy',
#   'tokenId': 53},
#  {'Background': 'Pink',
#   'Banana Base': 'Yellow',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Pixel',
#   'Head Gear': 'Vintage',
#   'tokenId': 54},
#  {'Background': 'Pink',
#   'Banana Base': 'Red',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Ahoy',
#   'tokenId': 55},
#  {'Background': 'Lilac',
#   'Banana Base': 'Green',
#   'Mouth': 'Toothless',
#   'Eyes': 'The Green Gaze',
#   'Head Gear': 'Quinn',
#   'tokenId': 56},
#  {'Background': 'Mint',
#   'Banana Base': 'Green',
#   'Mouth': 'Toothless',
#   'Eyes': 'Raphael',
#   'Head Gear': 'Goku',
#   'tokenId': 57},
#  {'Background': 'Lilac',
#   'Banana Base': 'Wonderland',
#   'Mouth': 'Meh',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 58},
#  {'Background': 'Pink',
#   'Banana Base': 'Pride',
#   'Mouth': 'Happy',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Abu',
#   'tokenId': 59},
#  {'Background': 'Mint',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Googly',
#   'Head Gear': 'Quinn',
#   'tokenId': 60},
#  {'Background': 'Pink',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Happy',
#   'Eyes': 'Bored',
#   'Head Gear': 'Demon',
#   'tokenId': 61},
#  {'Background': 'Grey',
#   'Banana Base': 'Red',
#   'Mouth': 'Lollipop',
#   'Eyes': 'Bulge',
#   'Head Gear': 'Fury',
#   'tokenId': 62},
#  {'Background': 'Grey',
#   'Banana Base': 'Green',
#   'Mouth': 'Cherry Lips',
#   'Eyes': '3D',
#   'Head Gear': 'Ahoy',
#   'tokenId': 63},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Bubblegum',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Dood',
#   'tokenId': 64},
#  {'Background': 'Lilac',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Whistle',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 65},
#  {'Background': 'Mint',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Spike',
#   'tokenId': 66},
#  {'Background': 'Northern Lights',
#   'Banana Base': 'Red',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Carnival',
#   'Head Gear': 'Bowl',
#   'tokenId': 67},
#  {'Background': 'Lilac',
#   'Banana Base': 'Blue',
#   'Mouth': 'Sulking',
#   'Eyes': 'Cyclops',
#   'Head Gear': 'Raiden',
#   'tokenId': 68},
#  {'Background': 'Mint',
#   'Banana Base': 'Pride',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Cross-eyed',
#   'Head Gear': 'Deputy',
#   'tokenId': 69},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Doobie',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Goku',
#   'tokenId': 70},
#  {'Background': 'Grey',
#   'Banana Base': 'Green',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Donatello',
#   'Head Gear': 'Fury',
#   'tokenId': 71},
#  {'Background': 'Grey',
#   'Banana Base': 'Green',
#   'Mouth': 'Trashy',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Wilma',
#   'tokenId': 72},
#  {'Background': 'Lilac',
#   'Banana Base': 'Blue',
#   'Mouth': 'Happy',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Sheriff ',
#   'tokenId': 73},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Pride',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Donatello',
#   'Head Gear': 'Vintage',
#   'tokenId': 74},
#  {'Background': 'Lilac',
#   'Banana Base': 'Wonderland',
#   'Mouth': 'Happy',
#   'Eyes': 'Bana-love',
#   'Head Gear': 'Bowl',
#   'tokenId': 75},
#  {'Background': 'Pink',
#   'Banana Base': 'Green',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Donatello',
#   'Head Gear': 'Mullet',
#   'tokenId': 76},
#  {'Background': 'Lilac',
#   'Banana Base': 'Blue',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Bulge',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 77},
#  {'Background': 'Northern Lights',
#   'Banana Base': 'Yellow',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Geeky',
#   'Head Gear': 'Boogie-Beanie',
#   'tokenId': 78},
#  {'Background': 'Grey',
#   'Banana Base': 'Pride',
#   'Mouth': 'Smirk',
#   'Eyes': 'Trippy',
#   'Head Gear': 'Donald Duck',
#   'tokenId': 79},
#  {'Background': 'Tag it',
#   'Banana Base': 'Red',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Cross-eyed',
#   'Head Gear': 'Boogie-Beanie',
#   'tokenId': 80},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': 'Whistle',
#   'Eyes': 'Googly',
#   'Head Gear': 'Bonnet',
#   'tokenId': 81},
#  {'Background': 'Downtown',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Googly',
#   'Head Gear': 'Bonnet',
#   'tokenId': 82},
#  {'Background': 'Lilac',
#   'Banana Base': 'Green',
#   'Mouth': 'The Douche',
#   'Eyes': 'Trippy',
#   'Head Gear': 'Bleach',
#   'tokenId': 83},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Red',
#   'Mouth': 'Meh',
#   'Eyes': 'Googly',
#   'Head Gear': 'Bonnet',
#   'tokenId': 84},
#  {'Background': 'Pink',
#   'Banana Base': 'Pride',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Mullet',
#   'tokenId': 85},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Blue',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'Abu',
#   'tokenId': 86},
#  {'Background': 'Mint',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Dystopia',
#   'Eyes': 'Bored',
#   'Head Gear': 'Toupet',
#   'tokenId': 87},
#  {'Background': 'Lilac',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Geeky',
#   'Head Gear': 'Tuft',
#   'tokenId': 88},
#  {'Background': 'Pink',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Pipe',
#   'Eyes': 'Bored',
#   'Head Gear': 'Sheriff ',
#   'tokenId': 89},
#  {'Background': 'Pink',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Toothless',
#   'Eyes': 'Wazowski',
#   'Head Gear': 'Raiden',
#   'tokenId': 90},
#  {'Background': 'Pink',
#   'Banana Base': 'Red',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Deputy',
#   'tokenId': 91},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Bored',
#   'Head Gear': 'Abu',
#   'tokenId': 92},
#  {'Background': 'Mint',
#   'Banana Base': 'Peeled',
#   'Mouth': 'Cigar',
#   'Eyes': 'Bulge',
#   'Head Gear': 'Abu',
#   'tokenId': 93},
#  {'Background': 'Lilac',
#   'Banana Base': 'Iridescent',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': '3D',
#   'Head Gear': 'Bowl',
#   'tokenId': 94},
#  {'Background': 'Downtown',
#   'Banana Base': 'Pride',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Ryu',
#   'tokenId': 95},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Smirk',
#   'Eyes': 'Conductor',
#   'Head Gear': 'Ryu',
#   'tokenId': 96},
#  {'Background': 'Pink',
#   'Banana Base': 'Green',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Pixel',
#   'Head Gear': 'Jester',
#   'tokenId': 97},
#  {'Background': 'Northern Lights',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Lollipop',
#   'Eyes': 'Donatello',
#   'Head Gear': 'Raiden',
#   'tokenId': 98},
#  {'Background': 'Lilac',
#   'Banana Base': 'Pride',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': '3D',
#   'Head Gear': 'Mullet',
#   'tokenId': 99},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Red',
#   'Mouth': 'Toothless',
#   'Eyes': 'Mysterious',
#   'Head Gear': 'Rapunzel',
#   'tokenId': 100},
#  {'Background': 'Amber',
#   'Banana Base': 'Blue',
#   'Mouth': 'Bubblegum',
#   'Eyes': 'Bored',
#   'Head Gear': 'Goku',
#   'tokenId': 101},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Red',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Goofy',
#   'tokenId': 102},
#  {'Background': 'Sherbert',
#   'Banana Base': 'Peeled',
#   'Mouth': 'Lollipop',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 103},
#  {'Background': 'Grey',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Whoops',
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Abu',
#   'tokenId': 104},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Red',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Cross-eyed',
#   'Head Gear': 'Deputy',
#   'tokenId': 105},
#  {'Background': 'Pink',
#   'Banana Base': 'Blue',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Bored',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 106},
#  {'Background': 'Grey',
#   'Banana Base': 'Blue',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': '3D',
#   'Head Gear': 'Deputy',
#   'tokenId': 107},
#  {'Background': 'Grey',
#   'Banana Base': 'Blue',
#   'Mouth': 'Doobie',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Mullet',
#   'tokenId': 108},
#  {'Background': 'Pink',
#   'Banana Base': 'Pride',
#   'Mouth': 'Pipe',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Deputy',
#   'tokenId': 109},
#  {'Background': 'Mint',
#   'Banana Base': 'Green',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Sheriff ',
#   'tokenId': 110},
#  {'Background': 'Grey',
#   'Banana Base': 'Pride',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Geeky',
#   'Head Gear': 'Deputy',
#   'tokenId': 111},
#  {'Background': 'Pink',
#   'Banana Base': 'Red',
#   'Mouth': 'Toothless',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Tuft',
#   'tokenId': 112},
#  {'Background': 'Lilac',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Cross-eyed',
#   'Head Gear': 'Bowl',
#   'tokenId': 113},
#  {'Background': 'Pink',
#   'Banana Base': 'Green',
#   'Mouth': 'Happy',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Abu',
#   'tokenId': 114},
#  {'Background': 'Grey',
#   'Banana Base': 'Wonderland',
#   'Mouth': 'Whoops',
#   'Eyes': 'Wazowski',
#   'Head Gear': 'Fury',
#   'tokenId': 115},
#  {'Background': 'Sherbert',
#   'Banana Base': 'Yellow',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Trippy',
#   'Head Gear': 'Dood',
#   'tokenId': 116},
#  {'Background': 'Pink',
#   'Banana Base': 'Yellow',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Boogie-Beanie',
#   'tokenId': 117},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Blue',
#   'Mouth': 'Toothless',
#   'Eyes': 'The Green Gaze',
#   'Head Gear': 'Mullet',
#   'tokenId': 118},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 119},
#  {'Background': 'Pink',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Smirk',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Quinn',
#   'tokenId': 120},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Trippy',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 121},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': 'Sulking',
#   'Eyes': 'Cyclops',
#   'Head Gear': 'Mullet',
#   'tokenId': 122},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Green',
#   'Mouth': 'Toothpick',
#   'Eyes': '3D',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 123},
#  {'Background': 'Mint',
#   'Banana Base': 'Pride',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 124},
#  {'Background': 'Amber',
#   'Banana Base': 'Pride',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Crown',
#   'tokenId': 125},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Blue',
#   'Mouth': 'Whistle',
#   'Eyes': 'Bored',
#   'Head Gear': 'Goofy',
#   'tokenId': 126},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Red',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Jester',
#   'tokenId': 127},
#  {'Background': 'Lilac',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Doobie',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Ryu',
#   'tokenId': 128},
#  {'Background': 'Lilac',
#   'Banana Base': 'Blue',
#   'Mouth': 'Happy',
#   'Eyes': 'Bana-love',
#   'Head Gear': 'Ahoy',
#   'tokenId': 129},
#  {'Background': 'Grey',
#   'Banana Base': 'Psychedelic',
#   'Mouth': 'Sulking',
#   'Eyes': 'Bored',
#   'Head Gear': 'Bleach',
#   'tokenId': 130},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Geeky',
#   'Head Gear': 'Demon',
#   'tokenId': 131},
#  {'Background': 'Lilac',
#   'Banana Base': 'Green',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'Bonnet',
#   'tokenId': 132},
#  {'Background': 'Grey',
#   'Banana Base': 'Peeled',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Goofy',
#   'tokenId': 133},
#  {'Background': 'Lilac',
#   'Banana Base': 'Green',
#   'Mouth': 'Cigar',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Raiden',
#   'tokenId': 134},
#  {'Background': 'Pink',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Meh',
#   'Eyes': 'Mysterious',
#   'Head Gear': 'Abu',
#   'tokenId': 135},
#  {'Background': 'Tag it',
#   'Banana Base': 'Psychedelic',
#   'Mouth': 'Smirk',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Deputy',
#   'tokenId': 136},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Red',
#   'Mouth': 'Happy',
#   'Eyes': '3D',
#   'Head Gear': 'Wilma',
#   'tokenId': 137},
#  {'Background': 'Pink',
#   'Banana Base': 'Blue',
#   'Mouth': 'Doobie',
#   'Eyes': 'Bored',
#   'Head Gear': 'Boogie-Beanie',
#   'tokenId': 138},
#  {'Background': 'Mint',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Goku',
#   'tokenId': 139},
#  {'Background': 'Sherbert',
#   'Banana Base': 'Blue',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': '3D',
#   'Head Gear': 'Ahoy',
#   'tokenId': 140},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Fury',
#   'tokenId': 141},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Peeled Pickle',
#   'Mouth': 'Meh',
#   'Eyes': 'Bored',
#   'Head Gear': 'Cotton Candy',
#   'tokenId': 142},
#  {'Background': 'Mint',
#   'Banana Base': 'Pride',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Boogie-Beanie',
#   'tokenId': 143},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': 'Toothless',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Toupet',
#   'tokenId': 144},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Red',
#   'Mouth': 'Smirk',
#   'Eyes': 'Bored',
#   'Head Gear': 'Raiden',
#   'tokenId': 145},
#  {'Background': 'Lilac',
#   'Banana Base': 'Blue',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Bleach',
#   'tokenId': 146},
#  {'Background': 'Mint',
#   'Banana Base': 'Peeled Pickle',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Donatello',
#   'Head Gear': 'Wilma',
#   'tokenId': 147},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Cyclops',
#   'Head Gear': 'Sporty',
#   'tokenId': 148},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Blue',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Mullet',
#   'tokenId': 149},
#  {'Background': 'Lilac',
#   'Banana Base': 'Stripes',
#   'Mouth': 'Toothless',
#   'Eyes': 'Bored',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 150},
#  {'Background': 'Downtown',
#   'Banana Base': 'Green',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Dood',
#   'tokenId': 151},
#  {'Background': 'Mint',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Meh',
#   'Eyes': 'Wazowski',
#   'Head Gear': 'Bowl',
#   'tokenId': 152},
#  {'Background': 'Pink',
#   'Banana Base': 'Peeled',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Cyclops',
#   'Head Gear': 'Deputy',
#   'tokenId': 153},
#  {'Background': 'Lilac',
#   'Banana Base': 'Green',
#   'Mouth': 'Meh',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Bowl',
#   'tokenId': 154},
#  {'Background': 'Mint',
#   'Banana Base': 'Green',
#   'Mouth': 'Smirk',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Sporty',
#   'tokenId': 155},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Whistle',
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'Sporty',
#   'tokenId': 156},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Pride',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Trippy',
#   'Head Gear': 'DJ',
#   'tokenId': 157},
#  {'Background': 'Lilac',
#   'Banana Base': 'Peeled',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Bana-love',
#   'Head Gear': 'Fury',
#   'tokenId': 158},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': 'Trashy',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Bowl',
#   'tokenId': 159},
#  {'Background': 'Pink',
#   'Banana Base': 'Pride',
#   'Mouth': 'Meh',
#   'Eyes': 'Googly',
#   'Head Gear': 'Vintage',
#   'tokenId': 160},
#  {'Background': 'Amber',
#   'Banana Base': 'Blue',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Bulge',
#   'Head Gear': 'Dood',
#   'tokenId': 161},
#  {'Background': 'Lilac',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Whistle',
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'Vintage',
#   'tokenId': 162},
#  {'Background': 'Grey',
#   'Banana Base': 'Peeled',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Mullet',
#   'tokenId': 163},
#  {'Background': 'Mint',
#   'Banana Base': 'Pride',
#   'Mouth': 'Smirk',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 164},
#  {'Background': 'Grey',
#   'Banana Base': 'Yellow',
#   'Mouth': 'The Douche',
#   'Eyes': 'Googly',
#   'Head Gear': 'Bonnet',
#   'tokenId': 165},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Pride',
#   'Mouth': 'Doobie',
#   'Eyes': 'Bored',
#   'Head Gear': 'Goku',
#   'tokenId': 166},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Pride',
#   'Mouth': 'Meh',
#   'Eyes': 'Bulge',
#   'Head Gear': 'Goku',
#   'tokenId': 167},
#  {'Background': 'Amber',
#   'Banana Base': 'Green',
#   'Mouth': 'Meh',
#   'Eyes': 'The Green Gaze',
#   'Head Gear': 'Raiden',
#   'tokenId': 168},
#  {'Background': 'Northern Lights',
#   'Banana Base': 'Red',
#   'Mouth': 'The Douche',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Dood',
#   'tokenId': 169},
#  {'Background': 'Pink',
#   'Banana Base': 'Blue',
#   'Mouth': 'Toothless',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Fury',
#   'tokenId': 170},
#  {'Background': 'Mint',
#   'Banana Base': 'Green',
#   'Mouth': 'Happy',
#   'Eyes': 'Bulge',
#   'Head Gear': 'Ahoy',
#   'tokenId': 171},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Green',
#   'Mouth': 'Smirk',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Raiden',
#   'tokenId': 172},
#  {'Background': 'Grey',
#   'Banana Base': 'Pride',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Boogie-Beanie',
#   'tokenId': 173},
#  {'Background': 'Grey',
#   'Banana Base': 'Green',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Ahoy',
#   'tokenId': 174},
#  {'Background': 'Sherbert',
#   'Banana Base': 'Pride',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 175},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Quinn',
#   'tokenId': 176},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': 'Bubblegum',
#   'Eyes': '3D',
#   'Head Gear': 'Bowl',
#   'tokenId': 177},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 178},
#  {'Background': 'Grey',
#   'Banana Base': 'Green',
#   'Mouth': 'Sulking',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Ahoy',
#   'tokenId': 179},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 180},
#  {'Background': 'Grey',
#   'Banana Base': 'Psychedelic',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Raiden',
#   'tokenId': 181},
#  {'Background': 'Lilac',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Smirk',
#   'Eyes': 'Googly',
#   'Head Gear': 'Raiden',
#   'tokenId': 182},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Green',
#   'Mouth': 'Whistle',
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Goofy',
#   'tokenId': 183},
#  {'Background': 'Grey',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Sheriff ',
#   'tokenId': 184},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Green',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Cyclops',
#   'Head Gear': 'Bowl',
#   'tokenId': 185},
#  {'Background': 'Mint',
#   'Banana Base': 'Green',
#   'Mouth': 'Bubblegum',
#   'Eyes': 'Conductor',
#   'Head Gear': 'Fury',
#   'tokenId': 186},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Blue',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Cross-eyed',
#   'Head Gear': 'Goofy',
#   'tokenId': 187},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Blue',
#   'Mouth': 'Smirk',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Donald Duck',
#   'tokenId': 188},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Camo',
#   'Mouth': 'Toothless',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Toupet',
#   'tokenId': 189},
#  {'Background': 'Mint',
#   'Banana Base': 'Yellow',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Geeky',
#   'Head Gear': 'Tiara',
#   'tokenId': 190},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Red',
#   'Mouth': 'The Douche',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Goku',
#   'tokenId': 191},
#  {'Background': 'Tag it',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Dood',
#   'tokenId': 192},
#  {'Background': 'Grey',
#   'Banana Base': 'Red',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Raiden',
#   'tokenId': 193},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Green',
#   'Mouth': 'Happy',
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Sheriff ',
#   'tokenId': 194},
#  {'Background': 'Mint',
#   'Banana Base': 'Green',
#   'Mouth': 'Toothless',
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 195},
#  {'Background': 'Pink',
#   'Banana Base': 'Pride',
#   'Mouth': 'Meh',
#   'Eyes': 'Wazowski',
#   'Head Gear': 'Donald Duck',
#   'tokenId': 196},
#  {'Background': 'Lilac',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Bana-love',
#   'Head Gear': 'Toupet',
#   'tokenId': 197},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Pipe',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Bleach',
#   'tokenId': 198},
#  {'Background': 'Amber',
#   'Banana Base': 'Stripes',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 199},
#  {'Background': 'Mint',
#   'Banana Base': 'Green',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Bana-love',
#   'Head Gear': 'Demon',
#   'tokenId': 200},
#  {'Background': 'Mint',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Lollipop',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Mullet',
#   'tokenId': 201},
#  {'Background': 'Pink',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Toupet',
#   'tokenId': 202},
#  {'Background': 'Northern Lights',
#   'Banana Base': 'Green',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Geeky',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 203},
#  {'Background': 'Pink',
#   'Banana Base': 'Blue',
#   'Mouth': 'Bubblegum',
#   'Eyes': 'Googly',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 204},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Trashy',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Fury',
#   'tokenId': 205},
#  {'Background': 'Grey',
#   'Banana Base': 'Psychedelic',
#   'Mouth': 'Lollipop',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Wilma',
#   'tokenId': 206},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Emerald',
#   'Mouth': 'Whistle',
#   'Eyes': 'Bored',
#   'Head Gear': 'Cotton Candy',
#   'tokenId': 207},
#  {'Background': 'Grey',
#   'Banana Base': 'Red',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'Deputy',
#   'tokenId': 208},
#  {'Background': 'Grey',
#   'Banana Base': 'Blue',
#   'Mouth': 'Pipe',
#   'Eyes': 'Bulge',
#   'Head Gear': 'Boogie-Beanie',
#   'tokenId': 209},
#  {'Background': 'Grey',
#   'Banana Base': 'Blue',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Geeky',
#   'Head Gear': 'Vintage',
#   'tokenId': 210},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Red',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Donatello',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 211},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Ahoy',
#   'tokenId': 212},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 213},
#  {'Background': 'Grey',
#   'Banana Base': 'Iridescent',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Wazowski',
#   'Head Gear': 'Cotton Candy',
#   'tokenId': 214},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Steampunk',
#   'Head Gear': 'Spike',
#   'tokenId': 215},
#  {'Background': 'Grey',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Doobie',
#   'Eyes': 'Cyclops',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 216},
#  {'Background': 'Downtown',
#   'Banana Base': 'Green',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Crown',
#   'tokenId': 217},
#  {'Background': 'Pink',
#   'Banana Base': 'Green',
#   'Mouth': 'Cigar',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Toupet',
#   'tokenId': 218},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Raiden',
#   'tokenId': 219},
#  {'Background': 'Downtown',
#   'Banana Base': 'Blue',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Geeky',
#   'Head Gear': 'DJ',
#   'tokenId': 220},
#  {'Background': 'Grey',
#   'Banana Base': 'Red',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Flirty',
#   'Head Gear': 'Goofy',
#   'tokenId': 221},
#  {'Background': 'Northern Lights',
#   'Banana Base': 'Blue',
#   'Mouth': 'Lollipop',
#   'Eyes': '3D',
#   'Head Gear': 'Sporty',
#   'tokenId': 222},
#  {'Background': 'Amber',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Pipe',
#   'Eyes': 'Googly',
#   'Head Gear': 'Abu',
#   'tokenId': 223},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Green',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 224},
#  {'Background': 'Northern Lights',
#   'Banana Base': 'Green',
#   'Mouth': 'Smirk',
#   'Eyes': 'Geeky',
#   'Head Gear': 'Ahoy',
#   'tokenId': 225},
#  {'Background': 'Grey',
#   'Banana Base': 'Green',
#   'Mouth': 'Happy',
#   'Eyes': 'Geeky',
#   'Head Gear': 'Goku',
#   'tokenId': 226},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Whistle',
#   'Eyes': '3D',
#   'Head Gear': 'Sheriff ',
#   'tokenId': 227},
#  {'Background': 'Grey',
#   'Banana Base': 'Red',
#   'Mouth': 'Whistle',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Spike',
#   'tokenId': 228},
#  {'Background': 'Mint',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Meh',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Spike',
#   'tokenId': 229},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Bulge',
#   'Head Gear': 'Crown',
#   'tokenId': 230},
#  {'Background': 'Amber',
#   'Banana Base': 'Pride',
#   'Mouth': 'Bubblegum',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Vintage',
#   'tokenId': 231},
#  {'Background': 'Pink',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Boogie-Beanie',
#   'tokenId': 232},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Goku',
#   'tokenId': 233},
#  {'Background': 'Mint',
#   'Banana Base': 'Green',
#   'Mouth': 'Doobie',
#   'Eyes': 'Carnival',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 234},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Pride',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Wazowski',
#   'Head Gear': 'Donald Duck',
#   'tokenId': 235},
#  {'Background': 'Lilac',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Pipe',
#   'Eyes': 'Googly',
#   'Head Gear': 'Fury',
#   'tokenId': 236},
#  {'Background': 'Northern Lights',
#   'Banana Base': 'Pride',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Cross-eyed',
#   'Head Gear': 'Toupet',
#   'tokenId': 237},
#  {'Background': 'Lilac',
#   'Banana Base': 'Green',
#   'Mouth': 'Toothless',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Bonnet',
#   'tokenId': 238},
#  {'Background': 'Grey',
#   'Banana Base': 'Blue',
#   'Mouth': 'Whistle',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Spike',
#   'tokenId': 239},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Toupet',
#   'tokenId': 240},
#  {'Background': 'Mint',
#   'Banana Base': 'Psychedelic',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Cross-eyed',
#   'Head Gear': 'Donald Duck',
#   'tokenId': 241},
#  {'Background': 'Lilac',
#   'Banana Base': 'Peeled',
#   'Mouth': 'Happy',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Donald Duck',
#   'tokenId': 242},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Sporty',
#   'tokenId': 243},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Trippy',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 244},
#  {'Background': 'Mint',
#   'Banana Base': 'Green',
#   'Mouth': 'Bubblegum',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Vintage',
#   'tokenId': 245},
#  {'Background': 'Lilac',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Cyclops',
#   'Head Gear': 'Sheriff ',
#   'tokenId': 246},
#  {'Background': 'Northern Lights',
#   'Banana Base': 'Green',
#   'Mouth': 'Meh',
#   'Eyes': 'Conductor',
#   'Head Gear': 'Abu',
#   'tokenId': 247},
#  {'Background': 'Grey',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Meh',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Goku',
#   'tokenId': 248},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Trashy',
#   'Eyes': 'Bored',
#   'Head Gear': 'Dood',
#   'tokenId': 249},
#  {'Background': 'Grey',
#   'Banana Base': 'Blue',
#   'Mouth': 'Happy',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Sheriff ',
#   'tokenId': 250},
#  {'Background': 'Pink',
#   'Banana Base': 'Yellow',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Googly',
#   'Head Gear': 'Bowl',
#   'tokenId': 251},
#  {'Background': 'Lilac',
#   'Banana Base': 'Blue',
#   'Mouth': 'Smirk',
#   'Eyes': 'Googly',
#   'Head Gear': 'Quinn',
#   'tokenId': 252},
#  {'Background': 'Sherbert',
#   'Banana Base': 'Pride',
#   'Mouth': 'Pipe',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Crown',
#   'tokenId': 253},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Pride',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Deputy',
#   'tokenId': 254},
#  {'Background': 'Mint',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Smirk',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Ahoy',
#   'tokenId': 255},
#  {'Background': 'Lilac',
#   'Banana Base': 'Blue',
#   'Mouth': 'Happy',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Ahoy',
#   'tokenId': 256},
#  {'Background': 'Gold',
#   'Banana Base': 'Green',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Wazowski',
#   'Head Gear': 'Tuft',
#   'tokenId': 257},
#  {'Background': 'Grey',
#   'Banana Base': 'Blue',
#   'Mouth': 'Smirk',
#   'Eyes': 'Donatello',
#   'Head Gear': 'Bleach',
#   'tokenId': 258},
#  {'Background': 'Pink',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Bored',
#   'Head Gear': 'Mullet',
#   'tokenId': 259},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Green',
#   'Mouth': 'Dystopia',
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Dood',
#   'tokenId': 260},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': 'The Douche',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Fury',
#   'tokenId': 261},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Blue',
#   'Mouth': 'Meh',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Bleach',
#   'tokenId': 262},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Red',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Ryu',
#   'tokenId': 263},
#  {'Background': 'Grey',
#   'Banana Base': 'Blue',
#   'Mouth': 'Pipe',
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Deputy',
#   'tokenId': 264},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Green',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Geeky',
#   'Head Gear': 'Bonnet',
#   'tokenId': 265},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Green',
#   'Mouth': 'Smirk',
#   'Eyes': 'Googly',
#   'Head Gear': 'Deputy',
#   'tokenId': 266},
#  {'Background': 'Pink',
#   'Banana Base': 'Green',
#   'Mouth': 'Smirk',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Vintage',
#   'tokenId': 267},
#  {'Background': 'Lilac',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Doobie',
#   'Eyes': 'Bana-love',
#   'Head Gear': 'Goofy',
#   'tokenId': 268},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Camo',
#   'Mouth': 'Meh',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Mullet',
#   'tokenId': 269},
#  {'Background': 'Grey',
#   'Banana Base': 'Blue',
#   'Mouth': 'Meh',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Goofy',
#   'tokenId': 270},
#  {'Background': 'Amber',
#   'Banana Base': 'Pride',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Boogie-Beanie',
#   'tokenId': 271},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Googly',
#   'Head Gear': 'Sheriff ',
#   'tokenId': 272},
#  {'Background': 'Mint',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Ryu',
#   'tokenId': 273},
#  {'Background': 'Mint',
#   'Banana Base': 'Green',
#   'Mouth': 'Meh',
#   'Eyes': 'Bored',
#   'Head Gear': 'Goku',
#   'tokenId': 274},
#  {'Background': 'Lilac',
#   'Banana Base': 'Green',
#   'Mouth': 'Smirk',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Donald Duck',
#   'tokenId': 275},
#  {'Background': 'Grey',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Meh',
#   'Eyes': 'Raphael',
#   'Head Gear': 'Wilma',
#   'tokenId': 276},
#  {'Background': 'Lilac',
#   'Banana Base': 'Blue',
#   'Mouth': 'Pipe',
#   'Eyes': '3D',
#   'Head Gear': 'Toupet',
#   'tokenId': 277},
#  {'Background': 'Grey',
#   'Banana Base': 'Green',
#   'Mouth': 'Meh',
#   'Eyes': 'Googly',
#   'Head Gear': 'Bleach',
#   'tokenId': 278},
#  {'Background': 'Pink',
#   'Banana Base': 'Blue',
#   'Mouth': 'Cigar',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Sheriff ',
#   'tokenId': 279},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Red',
#   'Mouth': 'Happy',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 280},
#  {'Background': 'Downtown',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Deputy',
#   'tokenId': 281},
#  {'Background': 'Sherbert',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Doobie',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Bowl',
#   'tokenId': 282},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': 'Lollipop',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Bowl',
#   'tokenId': 283},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Toothless',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Cotton Candy',
#   'tokenId': 284},
#  {'Background': 'Mint',
#   'Banana Base': 'Green',
#   'Mouth': 'Whoops',
#   'Eyes': '3D',
#   'Head Gear': 'Sporty',
#   'tokenId': 285},
#  {'Background': 'Pink',
#   'Banana Base': 'Red',
#   'Mouth': 'Pipe',
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Vintage',
#   'tokenId': 286},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Wonderland',
#   'Mouth': 'Smirk',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Fury',
#   'tokenId': 287},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Green',
#   'Mouth': 'Lollipop',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Deputy',
#   'tokenId': 288},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Blue',
#   'Mouth': 'Happy',
#   'Eyes': '3D',
#   'Head Gear': 'Astronaut',
#   'tokenId': 289},
#  {'Background': 'Lilac',
#   'Banana Base': 'Wonderland',
#   'Mouth': 'Toothless',
#   'Eyes': 'Carnival',
#   'Head Gear': 'Sporty',
#   'tokenId': 290},
#  {'Background': 'Mint',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Beatnik',
#   'Eyes': '3D',
#   'Head Gear': 'Sporty',
#   'tokenId': 291},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': 'Toothless',
#   'Eyes': '3D',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 292},
#  {'Background': 'Amber',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 293},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': 'Pipe',
#   'Eyes': '3D',
#   'Head Gear': 'Bowl',
#   'tokenId': 294},
#  {'Background': 'Amber',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Cigar',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Deputy',
#   'tokenId': 295},
#  {'Background': 'Mint',
#   'Banana Base': 'Pride',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Bored',
#   'Head Gear': 'Tuft',
#   'tokenId': 296},
#  {'Background': 'Mint',
#   'Banana Base': 'Psychedelic',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Steampunk',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 297},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'Vintage',
#   'tokenId': 298},
#  {'Background': 'Pink',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Smirk',
#   'Eyes': 'Steampunk',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 299},
#  {'Background': 'Grey',
#   'Banana Base': 'Red',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Hangover',
#   'Head Gear': 'Vintage',
#   'tokenId': 300},
#  {'Background': 'Pink',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Googly',
#   'Head Gear': 'Donald Duck',
#   'tokenId': 301},
#  {'Background': 'Mint',
#   'Banana Base': 'Green',
#   'Mouth': 'Whistle',
#   'Eyes': 'Bored',
#   'Head Gear': 'Raiden',
#   'tokenId': 302},
#  {'Background': 'Grey',
#   'Banana Base': 'Green',
#   'Mouth': 'The Douche',
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Ryu',
#   'tokenId': 303},
#  {'Background': 'Lilac',
#   'Banana Base': 'Blue',
#   'Mouth': 'Lollipop',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Dood',
#   'tokenId': 304},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Pride',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Bana-love',
#   'Head Gear': 'Dood',
#   'tokenId': 305},
#  {'Background': 'Lilac',
#   'Banana Base': 'Green',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Donatello',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 306},
#  {'Background': 'Downtown',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Cigar',
#   'Eyes': 'Raphael',
#   'Head Gear': 'Rapunzel',
#   'tokenId': 307},
#  {'Background': 'Pink',
#   'Banana Base': 'Pride',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Raiden',
#   'tokenId': 308},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Stripes',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Bleach',
#   'tokenId': 309},
#  {'Background': 'Lilac',
#   'Banana Base': 'Blue',
#   'Mouth': 'Meh',
#   'Eyes': 'Cross-eyed',
#   'Head Gear': 'Raiden',
#   'tokenId': 310},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Bubblegum',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Deputy',
#   'tokenId': 311},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Geeky',
#   'Head Gear': 'Deputy',
#   'tokenId': 312},
#  {'Background': 'Lilac',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Meh',
#   'Eyes': 'Googly',
#   'Head Gear': 'Astronaut',
#   'tokenId': 313},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Pride',
#   'Mouth': 'Lollipop',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Raiden',
#   'tokenId': 314},
#  {'Background': 'Pink',
#   'Banana Base': 'Green',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Fury',
#   'tokenId': 315},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Green',
#   'Mouth': 'Lollipop',
#   'Eyes': 'Bored',
#   'Head Gear': 'Sporty',
#   'tokenId': 316},
#  {'Background': 'Amber',
#   'Banana Base': 'Red',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Googly',
#   'Head Gear': 'Bleach',
#   'tokenId': 317},
#  {'Background': 'Mint',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Whistle',
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Fury',
#   'tokenId': 318},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Red',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Conductor',
#   'Head Gear': 'Fury',
#   'tokenId': 319},
#  {'Background': 'Downtown',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Whistle',
#   'Eyes': 'Raphael',
#   'Head Gear': 'Donald Duck',
#   'tokenId': 320},
#  {'Background': 'Lilac',
#   'Banana Base': 'Green',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Flirty',
#   'Head Gear': 'Abu',
#   'tokenId': 321},
#  {'Background': 'Downtown',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Vintage',
#   'tokenId': 322},
#  {'Background': 'Grey',
#   'Banana Base': 'Red',
#   'Mouth': 'Bubblegum',
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'DJ',
#   'tokenId': 323},
#  {'Background': 'Mint',
#   'Banana Base': 'Ruby',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Geeky',
#   'Head Gear': 'Ahoy',
#   'tokenId': 324},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Yellow',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'Goku',
#   'tokenId': 325},
#  {'Background': 'Lilac',
#   'Banana Base': 'Stripes',
#   'Mouth': 'Smirk',
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'Sporty',
#   'tokenId': 326},
#  {'Background': 'Pink',
#   'Banana Base': 'Red',
#   'Mouth': 'Meh',
#   'Eyes': 'Bored',
#   'Head Gear': 'Fury',
#   'tokenId': 327},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Cigar',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 328},
#  {'Background': 'Pink',
#   'Banana Base': 'Green',
#   'Mouth': 'Smirk',
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Fury',
#   'tokenId': 329},
#  {'Background': 'Pink',
#   'Banana Base': 'Green',
#   'Mouth': 'Bubblegum',
#   'Eyes': 'Donatello',
#   'Head Gear': 'Goofy',
#   'tokenId': 330},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Green',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Steampunk',
#   'Head Gear': 'Goku',
#   'tokenId': 331},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': 'Pipe',
#   'Eyes': 'Googly',
#   'Head Gear': 'Bonnet',
#   'tokenId': 332},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Green',
#   'Mouth': 'Meh',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Tuft',
#   'tokenId': 333},
#  {'Background': 'Mint',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Meh',
#   'Eyes': 'Cross-eyed',
#   'Head Gear': 'Deputy',
#   'tokenId': 334},
#  {'Background': 'Pink',
#   'Banana Base': 'Blue',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Trippy',
#   'Head Gear': 'Deputy',
#   'tokenId': 335},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Green',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Pixel',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 336},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Blue',
#   'Mouth': 'Lollipop',
#   'Eyes': '3D',
#   'Head Gear': 'Sporty',
#   'tokenId': 337},
#  {'Background': 'Grey',
#   'Banana Base': 'Red',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Bulge',
#   'Head Gear': 'Sporty',
#   'tokenId': 338},
#  {'Background': 'Grey',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Bubblegum',
#   'Eyes': 'Bored',
#   'Head Gear': 'Abu',
#   'tokenId': 339},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Green',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Carnival',
#   'Head Gear': 'Ahoy',
#   'tokenId': 340},
#  {'Background': 'Lilac',
#   'Banana Base': 'Green',
#   'Mouth': 'Meh',
#   'Eyes': 'Bored',
#   'Head Gear': 'Toupet',
#   'tokenId': 341},
# ...
#   'Banana Base': 'Green',
#   'Mouth': 'Toothless',
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Goofy',
#   'tokenId': 886},
#  {'Background': 'Grey',
#   'Banana Base': 'Blue',
#   'Mouth': 'Cigar',
#   'Eyes': 'Bored',
#   'Head Gear': 'Cotton Candy',
#   'tokenId': 887},
#  {'Background': 'Grey',
#   'Banana Base': 'Red',
#   'Mouth': 'Bubblegum',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Rapunzel',
#   'tokenId': 888},
#  {'Background': 'Pink',
#   'Banana Base': 'Pride',
#   'Mouth': 'Lollipop',
#   'Eyes': 'Trippy',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 889},
#  {'Background': 'Lilac',
#   'Banana Base': 'Camo',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Googly',
#   'Head Gear': 'Wilma',
#   'tokenId': 890},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Green',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Pixel',
#   'Head Gear': 'Bleach',
#   'tokenId': 891},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': 'Smirk',
#   'Eyes': 'Trippy',
#   'Head Gear': 'Bowl',
#   'tokenId': 892},
#  {'Background': 'Pink',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Toothless',
#   'Eyes': 'Bana-love',
#   'Head Gear': 'Abu',
#   'tokenId': 893},
#  {'Background': 'Pink',
#   'Banana Base': 'Green',
#   'Mouth': 'Lollipop',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Goku',
#   'tokenId': 894},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': 'Smirk',
#   'Eyes': 'Cross-eyed',
#   'Head Gear': 'Boogie-Beanie',
#   'tokenId': 895},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Green',
#   'Mouth': 'Happy',
#   'Eyes': 'Geeky',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 896},
#  {'Background': 'Mint',
#   'Banana Base': 'Pride',
#   'Mouth': 'Pipe',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Wilma',
#   'tokenId': 897},
#  {'Background': 'Downtown',
#   'Banana Base': 'Emerald',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Trippy',
#   'Head Gear': 'Deputy',
#   'tokenId': 898},
#  {'Background': 'Mint',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Pipe',
#   'Eyes': 'Cross-eyed',
#   'Head Gear': 'Astronaut',
#   'tokenId': 899},
#  {'Background': 'Lilac',
#   'Banana Base': 'Blue',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'Goofy',
#   'tokenId': 900},
#  {'Background': 'Grey',
#   'Banana Base': 'Green',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Geeky',
#   'Head Gear': 'Sporty',
#   'tokenId': 901},
#  {'Background': 'Mint',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Meh',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 902},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Wilma',
#   'tokenId': 903},
#  {'Background': 'Gold',
#   'Banana Base': 'Green',
#   'Mouth': 'Smirk',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Wilma',
#   'tokenId': 904},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Yellow',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Donatello',
#   'Head Gear': 'Toupet',
#   'tokenId': 905},
#  {'Background': 'Tag it',
#   'Banana Base': 'Red',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Bulge',
#   'Head Gear': 'Tuft',
#   'tokenId': 906},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Red',
#   'Mouth': 'Smirk',
#   'Eyes': 'Bored',
#   'Head Gear': 'Deputy',
#   'tokenId': 907},
#  {'Background': 'Grey',
#   'Banana Base': 'Blue',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Bowl',
#   'tokenId': 908},
#  {'Background': 'Northern Lights',
#   'Banana Base': 'Green',
#   'Mouth': 'Meh',
#   'Eyes': 'Googly',
#   'Head Gear': 'Sporty',
#   'tokenId': 909},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Toothless',
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Fury',
#   'tokenId': 910},
#  {'Background': 'Amber',
#   'Banana Base': 'Blue',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Steampunk',
#   'Head Gear': 'Vintage',
#   'tokenId': 911},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Trashy',
#   'Eyes': 'Googly',
#   'Head Gear': 'Dood',
#   'tokenId': 912},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Red',
#   'Mouth': 'Meh',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Boogie-Beanie',
#   'tokenId': 913},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': 'Bubblegum',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 914},
#  {'Background': 'Mint',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Cherry Lips',
#   'Eyes': '3D',
#   'Head Gear': 'Vintage',
#   'tokenId': 915},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Trashy',
#   'Eyes': 'Cyclops',
#   'Head Gear': 'Vintage',
#   'tokenId': 916},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Green',
#   'Mouth': 'Toothless',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 917},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Blue',
#   'Mouth': 'Meh',
#   'Eyes': 'Googly',
#   'Head Gear': 'Quinn',
#   'tokenId': 918},
#  {'Background': 'Pink',
#   'Banana Base': 'Blue',
#   'Mouth': 'Meh',
#   'Eyes': 'Steampunk',
#   'Head Gear': 'Ahoy',
#   'tokenId': 919},
#  {'Background': 'Lilac',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Geeky',
#   'Head Gear': 'Mullet',
#   'tokenId': 920},
#  {'Background': 'Amber',
#   'Banana Base': 'Yellow',
#   'Mouth': 'The Douche',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Goku',
#   'tokenId': 921},
#  {'Background': 'Grey',
#   'Banana Base': 'Red',
#   'Mouth': 'Beatnik',
#   'Eyes': '3D',
#   'Head Gear': 'Tuft',
#   'tokenId': 922},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Donatello',
#   'Head Gear': 'Toupet',
#   'tokenId': 923},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Blue',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Googly',
#   'Head Gear': 'Dood',
#   'tokenId': 924},
#  {'Background': 'Pink',
#   'Banana Base': 'Candy Camo',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Tuft',
#   'tokenId': 925},
#  {'Background': 'Pink',
#   'Banana Base': 'Green',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Cross-eyed',
#   'Head Gear': 'Wilma',
#   'tokenId': 926},
#  {'Background': 'Downtown',
#   'Banana Base': 'Blue',
#   'Mouth': 'Smirk',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Fury',
#   'tokenId': 927},
#  {'Background': 'Sherbert',
#   'Banana Base': 'Blue',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Goofy',
#   'tokenId': 928},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Blue',
#   'Mouth': 'Cigar',
#   'Eyes': 'Trippy',
#   'Head Gear': 'Sheriff ',
#   'tokenId': 929},
#  {'Background': 'Northern Lights',
#   'Banana Base': 'Wonderland',
#   'Mouth': 'Meh',
#   'Eyes': 'Bored',
#   'Head Gear': 'Bonnet',
#   'tokenId': 930},
#  {'Background': 'Amber',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Trashy',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Donald Duck',
#   'tokenId': 931},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Stripes',
#   'Mouth': 'Cigar',
#   'Eyes': 'Bored',
#   'Head Gear': 'Spike',
#   'tokenId': 932},
#  {'Background': 'Mint',
#   'Banana Base': 'Green',
#   'Mouth': 'Cigar',
#   'Eyes': 'Trippy',
#   'Head Gear': 'Deputy',
#   'tokenId': 933},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Red',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Bored',
#   'Head Gear': 'Raiden',
#   'tokenId': 934},
#  {'Background': 'Lilac',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Smirk',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Toupet',
#   'tokenId': 935},
#  {'Background': 'Amber',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Donatello',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 936},
#  {'Background': 'Tag it',
#   'Banana Base': 'Blue',
#   'Mouth': 'Lollipop',
#   'Eyes': 'Bulge',
#   'Head Gear': 'Crown',
#   'tokenId': 937},
#  {'Background': 'Grey',
#   'Banana Base': 'Emerald',
#   'Mouth': 'Toothless',
#   'Eyes': 'Cross-eyed',
#   'Head Gear': 'DJ',
#   'tokenId': 938},
#  {'Background': 'Grey',
#   'Banana Base': 'Red',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Trippy',
#   'Head Gear': 'Tiara',
#   'tokenId': 939},
#  {'Background': 'Pink',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Bonnet',
#   'tokenId': 940},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Bubblegum',
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Sporty',
#   'tokenId': 941},
#  {'Background': 'Grey',
#   'Banana Base': 'Blue',
#   'Mouth': 'Meh',
#   'Eyes': '3D',
#   'Head Gear': 'Cotton Candy',
#   'tokenId': 942},
#  {'Background': 'Pink',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Cyclops',
#   'Head Gear': 'Quinn',
#   'tokenId': 943},
#  {'Background': 'Lilac',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Lollipop',
#   'Eyes': 'Googly',
#   'Head Gear': 'Fury',
#   'tokenId': 944},
#  {'Background': 'Mint',
#   'Banana Base': 'Psychedelic',
#   'Mouth': 'Lollipop',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Tuft',
#   'tokenId': 945},
#  {'Background': 'Pink',
#   'Banana Base': 'Blue',
#   'Mouth': 'Whistle',
#   'Eyes': 'Mysterious',
#   'Head Gear': 'Sporty',
#   'tokenId': 946},
#  {'Background': 'Mint',
#   'Banana Base': 'Pride',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Boogie-Beanie',
#   'tokenId': 947},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Red',
#   'Mouth': 'Cigar',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 948},
#  {'Background': 'Lilac',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Cigar',
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 949},
#  {'Background': 'Grey',
#   'Banana Base': 'Green',
#   'Mouth': 'Happy',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Wilma',
#   'tokenId': 950},
#  {'Background': 'Amber',
#   'Banana Base': 'Blue',
#   'Mouth': 'Toothpick',
#   'Eyes': '3D',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 951},
#  {'Background': 'Pink',
#   'Banana Base': 'Yellow',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Leonardo',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 952},
#  {'Background': 'Grey',
#   'Banana Base': 'Blue',
#   'Mouth': 'Pipe',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Cotton Candy',
#   'tokenId': 953},
#  {'Background': 'Mint',
#   'Banana Base': 'Green',
#   'Mouth': 'Pipe',
#   'Eyes': 'Googly',
#   'Head Gear': 'Demon',
#   'tokenId': 954},
#  {'Background': 'Lilac',
#   'Banana Base': 'Psychedelic',
#   'Mouth': 'Pipe',
#   'Eyes': 'Conductor',
#   'Head Gear': 'Deputy',
#   'tokenId': 955},
#  {'Background': 'Downtown',
#   'Banana Base': 'Blue',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Angel',
#   'tokenId': 956},
#  {'Background': 'Pink',
#   'Banana Base': 'Blue',
#   'Mouth': 'Meh',
#   'Eyes': 'Bored',
#   'Head Gear': 'Bonnet',
#   'tokenId': 957},
#  {'Background': 'Lilac',
#   'Banana Base': 'Pride',
#   'Mouth': 'Whistle',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Bowl',
#   'tokenId': 958},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': 'Happy',
#   'Eyes': 'Geeky',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 959},
#  {'Background': 'Amber',
#   'Banana Base': 'Green',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Sidewinder',
#   'tokenId': 960},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Trippy',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 961},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Blue',
#   'Mouth': 'Sulking',
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'Bowl',
#   'tokenId': 962},
#  {'Background': 'Grey',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'The Douche',
#   'Eyes': 'Bored',
#   'Head Gear': 'Cotton Candy',
#   'tokenId': 963},
#  {'Background': 'Pink',
#   'Banana Base': 'Iridescent',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Cyclops',
#   'Head Gear': 'Sporty',
#   'tokenId': 964},
#  {'Background': 'Pink',
#   'Banana Base': 'Pride',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Hangover',
#   'Head Gear': 'Crown',
#   'tokenId': 965},
#  {'Background': 'Pink',
#   'Banana Base': 'Blue',
#   'Mouth': 'Trashy',
#   'Eyes': 'Bored',
#   'Head Gear': 'Jester',
#   'tokenId': 966},
#  {'Background': 'Mint',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Tuft',
#   'tokenId': 967},
#  {'Background': 'Amber',
#   'Banana Base': 'Peeled Pickle',
#   'Mouth': 'Whistle',
#   'Eyes': 'Bulge',
#   'Head Gear': 'Tuft',
#   'tokenId': 968},
#  {'Background': 'Lilac',
#   'Banana Base': 'Yellow',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Cyclops',
#   'Head Gear': 'Tuft',
#   'tokenId': 969},
#  {'Background': 'Pink',
#   'Banana Base': 'Green',
#   'Mouth': 'Whistle',
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Toupet',
#   'tokenId': 970},
#  {'Background': 'Mint',
#   'Banana Base': 'Blue',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Ryu',
#   'tokenId': 971},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Toothless',
#   'Eyes': 'Bored',
#   'Head Gear': 'Abu',
#   'tokenId': 972},
#  {'Background': 'Downtown',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Cigar',
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'Donald Duck',
#   'tokenId': 973},
#  {'Background': 'Mint',
#   'Banana Base': 'Green',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Bored',
#   'Head Gear': 'Bowl',
#   'tokenId': 974},
#  {'Background': 'Pink',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 975},
#  {'Background': 'Mint',
#   'Banana Base': 'Green',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Bana-love',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 976},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Wonderland',
#   'Mouth': 'Sulking',
#   'Eyes': 'Wazowski',
#   'Head Gear': 'Fury',
#   'tokenId': 977},
#  {'Background': 'Grey',
#   'Banana Base': 'Red',
#   'Mouth': "Handlebar 'stache",
#   'Eyes': 'Pixel',
#   'Head Gear': 'Sporty',
#   'tokenId': 978},
#  {'Background': 'Purple Haze',
#   'Banana Base': 'Red',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Dood',
#   'tokenId': 979},
#  {'Background': 'Sherbert',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Pipe',
#   'Eyes': 'Raphael',
#   'Head Gear': 'Goku',
#   'tokenId': 980},
#  {'Background': 'Mint',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Meh',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Abu',
#   'tokenId': 981},
#  {'Background': 'Grey',
#   'Banana Base': 'Red',
#   'Mouth': 'Happy',
#   'Eyes': 'Hypno',
#   'Head Gear': 'Goku',
#   'tokenId': 982},
#  {'Background': 'Lilac',
#   'Banana Base': 'Wonderland',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 983},
#  {'Background': 'Mint',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Bulge',
#   'Head Gear': 'Toupet',
#   'tokenId': 984},
#  {'Background': 'Northern Lights',
#   'Banana Base': 'Blue',
#   'Mouth': 'Smirk',
#   'Eyes': 'Flirty',
#   'Head Gear': 'Bleach',
#   'tokenId': 985},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Blue',
#   'Mouth': 'Tongue Ring',
#   'Eyes': 'Geeky',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 986},
#  {'Background': 'Pink',
#   'Banana Base': 'Candy Camo',
#   'Mouth': 'Happy',
#   'Eyes': 'Pixel',
#   'Head Gear': 'Quinn',
#   'tokenId': 987},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Lollipop',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Vintage',
#   'tokenId': 988},
#  {'Background': 'Mint',
#   'Banana Base': 'Iridescent',
#   'Mouth': 'Smirk',
#   'Eyes': 'Michelangelo',
#   'Head Gear': 'Mullet',
#   'tokenId': 989},
#  {'Background': 'Amber',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Grrrr',
#   'Eyes': 'Bana-love',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 990},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Blue',
#   'Mouth': 'Doobie',
#   'Eyes': 'Bored',
#   'Head Gear': 'Bonnet',
#   'tokenId': 991},
#  {'Background': 'Pink',
#   'Banana Base': 'Gold',
#   'Mouth': 'Smirk',
#   'Eyes': 'Stoner',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 992},
#  {'Background': 'Pink',
#   'Banana Base': 'Pride',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Cyberpunk',
#   'Head Gear': 'Hair Stick',
#   'tokenId': 993},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Toothpick',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Bonnet',
#   'tokenId': 994},
#  {'Background': 'Lilac',
#   'Banana Base': 'Red',
#   'Mouth': 'Beatnik',
#   'Eyes': 'Hangover',
#   'Head Gear': 'Cotton Candy',
#   'tokenId': 995},
#  {'Background': 'Amber',
#   'Banana Base': 'Blue',
#   'Mouth': 'Cherry Lips',
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Bowl',
#   'tokenId': 996},
#  {'Background': 'Mint',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Doobie',
#   'Eyes': 'Perplexed',
#   'Head Gear': 'Carrot Top',
#   'tokenId': 997},
#  {'Background': 'Mint',
#   'Banana Base': 'Red',
#   'Mouth': 'Sulking',
#   'Eyes': 'Bored',
#   'Head Gear': 'Tuft',
#   'tokenId': 998},
#  {'Background': 'Baby Blue',
#   'Banana Base': 'Yellow',
#   'Mouth': 'Smirk',
#   'Eyes': 'Eye-patch',
#   'Head Gear': 'Bleach',
#   'tokenId': 999},
#  ...]

# %%
#### IMAGE GENERATION
    
for item in traits:

    im1 = Image.open(f'./Backgrounds/{backgroundfiles[item["Background"]]}.jpg').convert('RGBA')
    im2 = Image.open(f'./Bananas/{bananafiles[item["Banana Base"]]}.png').convert('RGBA')
    im3 = Image.open(f'./Mouths/{mouthfiles[item["Mouth"]]}.png').convert('RGBA')
    im4 = Image.open(f'./Eyes/{eyefiles[item["Eyes"]]}.png').convert('RGBA')
    im5 = Image.open(f'./Headgear/{headgearfiles[item["Head Gear"]]}.png').convert('RGBA')


    #Create each composite
    com1 = Image.alpha_composite(im1, im2)
    com2 = Image.alpha_composite(com1, im3)
    com3 = Image.alpha_composite(com2, im4)
    com4 = Image.alpha_composite(com3, im5)

    #Convert to RGB
    rgb_im = com4.convert('RGB')
#     display(rgb_im.resize((400,400), Image.NEAREST))

    file_name = str(item["tokenId"]) + ".jpg"
    rgb_im.save("./output/" + file_name)
    print(f'{str(item["tokenId"])} done')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30980/3093663217.py in <module>
#       3 for item in traits:
#       4
# ----> 5     im1 = Image.open(f'./Backgrounds/{backgroundfiles[item["Background"]]}.jpg').convert('RGBA')
#       6     im2 = Image.open(f'./Bananas/{bananafiles[item["Banana Base"]]}.png').convert('RGBA')
#       7     im3 = Image.open(f'./Mouths/{mouthfiles[item["Mouth"]]}.png').convert('RGBA')
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2966
#    2967     if filename:
# -> 2968         fp = builtins.open(filename, "rb")
#    2969         exclusive_fp = True
#    2970
#
# FileNotFoundError: [Errno 2] No such file or directory: './Backgrounds/bg3.jpg'

# %%
# READ METADATA IF YOU ALREADY HAVE A JSON FILE

with open("traitsfinal.json", 'r') as f:
        traits = json.load(f)

# %%
traits[2050]

# %%
flip_ids = [8057, 8835, 8880, 6612, 5788, 8333, 2173, 8704, 7351, 6671, 4847, 5575, 4864, 2418, 2944, 5845, 552, 1161, 2390, 4383, 8126, 439, 1055, 3435, 7957, 1209, 6438, 6578, 6244, 3490, 4149, 8510, 113, 7193, 5728, 4731, 810, 2949, 3158, 1475, 1242, 4137, 7112, 5852, 7845, 3493, 377, 4272, 5494, 2919, 6818, 2828, 1089, 4914, 5054, 160, 3991, 7625, 6265, 8160, 7331, 4802, 1442, 3850, 171, 3469, 193, 7171, 6328, 5852, 6504, 6639, 2637, 1918, 8607, 4460, 5257, 926, 6114, 8428, 8173, 4565, 5857, 2021, 430, 7708, 4799, 8065, 1609, 4807, 5802, 3371, 8722, 5594, 3034, 2087, 3684, 7878, 7908]

# %%
for m in flip_ids:
    img = Image.open(f'./output/{str(m)}.jpg')
    im_mirror = ImageOps.mirror(img)
    im_mirror.save(f'./flipped/{str(m)}.jpg')

# %%
balds = [4378, 7459, 6945, 4644, 5999, 6337, 6675, 4179, 8467, 5482, 4531, 2016, 3790, 1305, 355]

for bald in balds:
    traits[bald]["Head Gear"] = "None"
    
#### BALDS
    
for bald in balds:
    
    item = traits[bald]
    
    im1 = Image.open(f'./Backgrounds/{backgroundfiles[item["Background"]]}.jpg').convert('RGBA')
    im2 = Image.open(f'./Bananas/{bananafiles[item["Banana Base"]]}.png').convert('RGBA')
    im3 = Image.open(f'./Mouths/{mouthfiles[item["Mouth"]]}.png').convert('RGBA')
    im4 = Image.open(f'./Eyes/{eyefiles[item["Eyes"]]}.png').convert('RGBA')
#     im5 = Image.open(f'./Headgear/{headgearfiles[item["Head Gear"]]}.png').convert('RGBA')


    #Create each composite
    com1 = Image.alpha_composite(im1, im2)
    com2 = Image.alpha_composite(com1, im3)
    com3 = Image.alpha_composite(com2, im4)
#     com4 = Image.alpha_composite(com3, im5)

    #Convert to RGB
    rgb_im = com3.convert('RGB')
#     display(rgb_im.resize((400,400), Image.NEAREST))

    file_name = str(item["tokenId"]) + ".jpg"
    rgb_im.save("./balds/" + file_name)
    print(f'{str(item["tokenId"])} done')

# %%
madboogielogos = [ 1334, 8120, 3430, 3439, 4175, 7710, 1842, 2428, 3553, 4764, 3439 ]

# %%
for logo in madboogielogos:

    im1 = Image.open(f'./output2/{logo}.jpg').convert('RGBA')
    im2 = Image.open(f'./Logo_static.png').convert('RGBA')
    com1 = Image.alpha_composite(im1, im2).convert('RGB')
    com1.save(f'./boogielogo/{logo}.jpg')

# %%
traits

# %%
with open('traitsfinal.json', 'w') as outfile:
    json.dump(traits, outfile, indent=4)
